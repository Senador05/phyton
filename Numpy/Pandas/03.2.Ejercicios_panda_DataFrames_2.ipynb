# %% [markdown]
# # Ejercicios Pandas DataFrames 02

# %% [markdown]
# Carga el dataset de vuelos "flights14.csv"

# %%
import pandas as pd

df = pd.read_csv('./data/flights14.csv')
df
# Out:
#         Unnamed: 0  year  month  day  dep_delay  arr_delay carrier origin  \
# 0                1  2014      1    1         14         13      AA    JFK
# 1                2  2014      1    1         -3         13      AA    JFK
# 2                3  2014      1    1          2          9      AA    JFK
# 3                4  2014      1    1         -8        -26      AA    LGA
# 4                5  2014      1    1          2          1      AA    JFK
# ...            ...   ...    ...  ...        ...        ...     ...    ...
# 253311      253312  2014     10   31          1        -30      UA    LGA
# 253312      253313  2014     10   31         -5        -14      UA    EWR
# 253313      253314  2014     10   31         -8         16      MQ    LGA
# 253314      253315  2014     10   31         -4         15      MQ    LGA
# 253315      253316  2014     10   31         -5          1      MQ    LGA
#
#        dest  air_time  distance  hour
# 0       LAX       359      2475     9
# 1       LAX       363      2475    11
# 2       LAX       351      2475    19
# 3       PBI       157      1035     7
# 4       LAX       350      2475    13
# ...     ...       ...       ...   ...
# 253311  IAH       201      1416    14
# 253312  IAH       189      1400     8
# 253313  RDU        83       431    11
# 253314  DTW        75       502    11
# 253315  SDF       110       659     8
#
# [253316 rows x 12 columns]

# %%
df = pd.read_csv('./data/flights14.csv', index_col=0)
df.head()
# Out:
#    year  month  day  dep_delay  arr_delay carrier origin dest  air_time  \
# 1  2014      1    1         14         13      AA    JFK  LAX       359
# 2  2014      1    1         -3         13      AA    JFK  LAX       363
# 3  2014      1    1          2          9      AA    JFK  LAX       351
# 4  2014      1    1         -8        -26      AA    LGA  PBI       157
# 5  2014      1    1          2          1      AA    JFK  LAX       350
#
#    distance  hour
# 1      2475     9
# 2      2475    11
# 3      2475    19
# 4      1035     7
# 5      2475    13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 253316 entries, 1 to 253316
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   year       253316 non-null  int64
#  1   month      253316 non-null  int64
#  2   day        253316 non-null  int64
#  3   dep_delay  253316 non-null  int64
#  4   arr_delay  253316 non-null  int64
#  5   carrier    253316 non-null  object
#  6   origin     253316 non-null  object
#  7   dest       253316 non-null  object
#  8   air_time   253316 non-null  int64
#  9   distance   253316 non-null  int64
#  10  hour       253316 non-null  int64
# dtypes: int64(8), object(3)
# memory usage: 23.2+ MB

# %% [markdown]
# 1. Escribe un programa Pandas para dividir los datos basados en origen y destino. Muestra cada grupo y el número de elementos por grupo

# %%
gdf = df.groupby(['origin','dest'])
print(gdf)
gdf.groups.items()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fd6a5c33280>
# dict_items([(('EWR', 'ALB'), Int64Index([  1111,   1646,   2178,   2184,   2799,   2820,   3345,   4117,
#               4773,   4885,
#             ...
#             120944, 121876, 122769, 123600, 124469, 124535, 148942, 150380,
#             151106, 248316],
#            dtype='int64', length=169)), (('EWR', 'ANC'), Int64Index([127051, 132934, 139219, 145470, 151274, 157519, 163580, 169256,
#             175934, 182363, 188665, 194812, 201109],
#            dtype='int64')), (('EWR', 'ATL'), Int64Index([   278,    283,    291,    296,    332,    335,    352,    369,
#                371,    409,
#             ...
#             252539, 252542, 252554, 252596, 252597, 252598, 253170, 253181,
#             253244, 253279],
#            dtype='int64', length=4182)), (('EWR', 'AUS'), Int64Index([   494,    708,   1206,   1349,   1782,   2264,   2889,   3036,
#               3481,   3679,
#             ...
#             249666, 250424, 250572, 251339, 251456, 252201, 252299, 252377,
#             253067, 253216],
#            dtype='int64', length=568)), (('EWR', 'AVL'), Int64Index([   372,   2166,   3334, 125430, 126366, 127107, 127952, 128871,
#             130676, 131520,
#             ...
#             245017, 245923, 246817, 247608, 248324, 249173, 250079, 250960,
#             251937, 252748],
#            dtype='int64', length=145)), (('EWR', 'AVP'), Int64Index([69984], dtype='int64')), (('EWR', 'BDL'), Int64Index([  4081,   4794,   4797,   4877,   5627,   5630,   5725,   6500,
#               6502,   6580,
#             ...
#             213429, 214325, 216128, 217102, 248228, 249059, 249963, 250848,
#             251829, 252716],
#            dtype='int64', length=210)), (('EWR', 'BNA'), Int64Index([   359,    378,    495,    496,   1105,   1207,   1208,   1640,
#               1696,   2163,
#             ...
#             251862, 251921, 252202, 252203, 252623, 252633, 252635, 252674,
#             253068, 253069],
#            dtype='int64', length=1797)), (('EWR', 'BOS'), Int64Index([    91,    230,    236,    585,    614,    672,    684,    689,
#                707,    731,
#             ...
#             253161, 253173, 253204, 253215, 253240, 253251, 253253, 253258,
#             253275, 253276],
#            dtype='int64', length=4268)), (('EWR', 'BQN'), Int64Index([   673,   1378,   1751,   2329,   2998,   5135,   6796,   7424,
#               8134,  10561,
#             ...
#             242185, 242964, 245526, 247305, 247960, 248860, 249671, 251514,
#             252303, 253266],
#            dtype='int64', length=251)), (('EWR', 'BTV'), Int64Index([  2176,   2818,   4058,   4096,   4816,   4857,   5650,   5699,
#               6518,   6557,
#             ...
#             217085, 217139, 218023, 218053, 218101, 249058, 249896, 250819,
#             251828, 252643],
#            dtype='int64', length=300)), (('EWR', 'BUF'), Int64Index([   431,   1126,   1634,   2189,   2813,   3341,   3403,   7225,
#               7861,  12805,
#             ...
#             244963, 245866, 246754, 247574, 249161, 250063, 250949, 251880,
#             251925, 252737],
#            dtype='int64', length=334)), (('EWR', 'BWI'), Int64Index([   394,   1108,   2171,   2781,   3339,   4059,   4803,   4809,
#               5601,   5642,
#             ...
#             124533, 124581, 151049, 204355, 248231, 249063, 249968, 250854,
#             251833, 252648],
#            dtype='int64', length=185)), (('EWR', 'BZN'), Int64Index([  2394,   2953,   7401,  13017,  17878,  23278,  27897,  32537,
#              38194,  38974,  44062,  44752,  49777,  50466,  55784,  56489,
#              61884,  62645,  67881,  68751, 127062, 127755, 132945, 133718,
#             139205, 139941, 145423, 146241, 151206, 152043, 154775, 157509,
#             158422, 160767, 163491, 164465, 167209, 169851, 170787, 173549,
#             176016, 176902, 179576, 182478, 183266, 185828, 188698, 189495,
#             194847, 195552, 201132],
#            dtype='int64')), (('EWR', 'CAE'), Int64Index([ 5657,  7958, 11183, 13543, 16003, 18411, 21497, 23739, 26057,
#             28322, 33026, 36393, 38678, 42219, 48220, 50791, 56842, 60417,
#             62998, 66577, 68938],
#            dtype='int64')), (('EWR', 'CHS'), Int64Index([   361,    368,    458,   1106,   1120,   2154,   2164,   2172,
#               2769,   2782,
#             ...
#             250855, 250873, 251807, 251823, 251834, 251852, 252627, 252639,
#             252649, 252663],
#            dtype='int64', length=986)), (('EWR', 'CLE'), Int64Index([   662,    671,    705,    720,   1354,   1376,   1786,   2146,
#               2148,   2227,
#             ...
#             251468, 251537, 252340, 252380, 252411, 252469, 253187, 253205,
#             253262, 253299],
#            dtype='int64', length=1171)), (('EWR', 'CLT'), Int64Index([   407,    410,    429,    432,    635,    638,    640,    645,
#                646,    653,
#             ...
#             252704, 252714, 252992, 253017, 253018, 253019, 253023, 253030,
#             253031, 253033],
#            dtype='int64', length=3921)), (('EWR', 'CMH'), Int64Index([  4796,   4823,   5629,   5655,   6591,   7844,   8638,   8664,
#               9483,   9513,
#             ...
#             249973, 249982, 250859, 250868, 251838, 251847, 252653, 252659,
#             252700, 252715],
#            dtype='int64', length=763)), (('EWR', 'CVG'), Int64Index([   404,    456,   1099,   1677,   2228,   3321,   3421,   4090,
#               4097,   4110,
#             ...
#             250943, 251824, 251858, 251866, 251877, 251920, 252640, 252668,
#             252688, 252703],
#            dtype='int64', length=1187)), (('EWR', 'DAY'), Int64Index([   351,    405,    412,   1129,   2147,   3406,   4028,   4775,
#               4853,   5603,
#             ...
#             249986, 250013, 250813, 250872, 250900, 251820, 251851, 251879,
#             252690, 252694],
#            dtype='int64', length=566)), (('EWR', 'DCA'), Int64Index([   354,    382,   1109,   2160,   2787,   3323,   3342,   3344,
#               4043,   4044,
#             ...
#             250874, 250875, 251830, 251844, 251853, 251854, 252644, 252658,
#             252664, 252665],
#            dtype='int64', length=1309)), (('EWR', 'DEN'), Int64Index([   497,    498,    607,    661,    676,    682,    722,    734,
#               1209,   1210,
#             ...
#             252416, 252431, 253070, 253071, 253188, 253196, 253209, 253212,
#             253225, 253269],
#            dtype='int64', length=2243)), (('EWR', 'DFW'), Int64Index([    19,     26,     43,     56,     63,    596,    759,    766,
#                782,    798,
#             ...
#             252321, 252364, 252448, 252796, 252828, 252832, 252837, 252852,
#             253168, 253236],
#            dtype='int64', length=2224)), (('EWR', 'DSM'), Int64Index([   403,   4091,   4851,   5694,   6551,   7893,   8699,   9548,
#              10317,  11221,
#             ...
#             215291, 216185, 217158, 218123, 248270, 249112, 250016, 250904,
#             251883, 252693],
#            dtype='int64', length=179)), (('EWR', 'DTW'), Int64Index([   321,    343,    362,    375,    385,    414,   1024,   1091,
#               1110,   1134,
#             ...
#             251831, 251832, 251839, 251899, 252509, 252538, 252599, 252646,
#             252647, 252712],
#            dtype='int64', length=2149)), (('EWR', 'EGE'), Int64Index([  680,  1384,  1757,  2335,  2999,  3569,  4366,  5141,  5995,
#              6801,  7354,  8141,  9010,  9779, 10566, 11599, 12426, 13045,
#             13762, 14604, 15082, 16265, 17339, 17907, 18653, 19438, 20179,
#             21081, 23305, 24008, 24520, 25214, 26430, 27232, 28605, 29433,
#             30219, 30921, 32500, 33269, 34187, 34898, 35921, 36621, 37501,
#             38153, 39011, 39896, 40822, 41704, 42687, 43564, 44021, 44791,
#             45490, 46283, 47111, 47880, 48808, 49719, 50535, 51441, 54144,
#             55070, 55815, 56531, 57545, 58262, 59237, 60300, 61118, 62729,
#             63542, 64462, 65311, 66260, 67227, 68003, 68694, 69601],
#            dtype='int64')), (('EWR', 'FLL'), Int64Index([    80,    108,    134,    167,    183,    570,    600,    602,
#                606,    618,
#             ...
#             252867, 252881, 252918, 253198, 253264, 253278, 253284, 253298,
#             253301, 253303],
#            dtype='int64', length=2909)), (('EWR', 'GRR'), Int64Index([   397,   1123,   2155,   3314,   4084,   4085,   4785,   4845,
#               5684,   5687,
#             ...
#             249103, 249114, 250008, 250020, 250894, 250907, 251873, 251885,
#             252684, 252696],
#            dtype='int64', length=490)), (('EWR', 'GSO'), Int64Index([   395,   1121,   1648,   2159,   2808,   3322,   3329,   3398,
#               4030,   4080,
#             ...
#             249163, 249165, 250065, 250067, 250951, 250953, 251926, 251928,
#             252701, 252739],
#            dtype='int64', length=644)), (('EWR', 'GSP'), Int64Index([   360,    396,   1107,   1630,   2186,   2768,   2785,   2811,
#               3319,   3340,
#             ...
#             250077, 250893, 250950, 250958, 251872, 251934, 251935, 252683,
#             252738, 252746],
#            dtype='int64', length=518)), (('EWR', 'HDN'), Int64Index([ 2377,  7379, 13088, 17855, 23258, 27902, 32517, 38172, 44041,
#             49792, 55763, 61861, 67862],
#            dtype='int64')), (('EWR', 'HNL'), Int64Index([   559,   1261,   1796,   2359,   3055,   3613,   4235,   5024,
#               5819,   6816,
#             ...
#             245559, 246369, 247377, 247972, 248790, 249745, 250557, 251460,
#             252398, 253192],
#            dtype='int64', length=301)), (('EWR', 'HOU'), Int64Index([   499,    500,   1211,   1212,   1699,   2267,   2268,   2893,
#               2894,   3486,
#             ...
#             250431, 251344, 251345, 251346, 252206, 252207, 252208, 253072,
#             253073, 253074],
#            dtype='int64', length=784)), (('EWR', 'IAD'), Int64Index([   433,    434,   1153,   1155,   1663,   1666,   2208,   2836,
#               3428,   3430,
#             ...
#             249167, 249881, 250068, 250069, 250954, 250955, 251929, 251930,
#             252741, 252742],
#            dtype='int64', length=629)), (('EWR', 'IAH'), Int64Index([   601,    604,    608,    629,    668,    691,    697,    729,
#                732,    733,
#             ...
#             253175, 253180, 253183, 253206, 253254, 253256, 253282, 253304,
#             253305, 253313],
#            dtype='int64', length=3073)), (('EWR', 'IND'), Int64Index([   365,    376,   1100,   1117,   1631,   1632,   2158,   2181,
#               2204,   3356,
#             ...
#             251806, 251808, 251848, 251871, 251878, 252626, 252628, 252645,
#             252660, 252689],
#            dtype='int64', length=1239)), (('EWR', 'JAC'), Int64Index([ 1340,  3607,  7357, 13048, 23309, 27837, 32586, 33270, 38135,
#             39012, 44792, 49751, 50541, 55845, 56536, 61935, 62734, 68033,
#             68697],
#            dtype='int64')), (('EWR', 'JAX'), Int64Index([   383,    389,    399,    413,   1116,   1137,   1653,   2180,
#               2197,   2794,
#             ...
#             251801, 251840, 251855, 251856, 251891, 252654, 252655, 252666,
#             252667, 252702],
#            dtype='int64', length=998)), (('EWR', 'LAS'), Int64Index([   619,    678,   1295,   1382,   1729,   1755,   1818,   2334,
#               2347,   3005,
#             ...
#             252310, 252356, 252358, 252409, 252410, 253155, 253178, 253203,
#             253271, 253311],
#            dtype='int64', length=1555)), (('EWR', 'LAX'), Int64Index([     6,    480,    481,    482,    572,    579,    587,    667,
#                696,    706,
#             ...
#             253164, 253177, 253190, 253193, 253200, 253214, 253263, 253280,
#             253295, 253310],
#            dtype='int64', length=4226)), (('EWR', 'MCI'), Int64Index([   373,    379,   1122,   1175,   1639,   2174,   2185,   2778,
#               2784,   2809,
#             ...
#             249981, 250005, 250806, 250867, 250891, 251812, 251846, 251870,
#             252632, 252681],
#            dtype='int64', length=995)), (('EWR', 'MCO'), Int64Index([   118,    124,    137,    168,    182,    205,    580,    605,
#                626,    677,
#             ...
#             252886, 252935, 252982, 253176, 253194, 253208, 253243, 253248,
#             253270, 253283],
#            dtype='int64', length=4164)), (('EWR', 'MDT'), Int64Index([7223, 12803, 17637, 23076, 27642], dtype='int64')), (('EWR', 'MDW'), Int64Index([   501,    502,    503,    504,    505,   1213,   1214,   1215,
#               1216,   1700,
#             ...
#             252211, 252212, 252213, 252214, 253075, 253076, 253077, 253078,
#             253079, 253080],
#            dtype='int64', length=1537)), (('EWR', 'MEM'), Int64Index([   358,    387,    402,   1128,   2149,   2814,   3317,   3351,
#               3405,   4035,
#             ...
#             249894, 250015, 250796, 250817, 250903, 251802, 251825, 251882,
#             252641, 252692],
#            dtype='int64', length=660)), (('EWR', 'MHT'), Int64Index([   353,   1628,   2151,   2190,   3313,   3427,   4072,   4118,
#               4777,   5668,
#             ...
#             214337, 214433, 215243, 215282, 216139, 216231, 217114, 217202,
#             218079, 229084],
#            dtype='int64', length=324)), (('EWR', 'MIA'), Int64Index([    11,     42,     60,    564,    576,    599,    702,    750,
#                781,    802,
#             ...
#             252434, 252809, 252830, 253024, 253026, 253197, 253226, 253294,
#             253302, 253307],
#            dtype='int64', length=2094)), (('EWR', 'MKE'), Int64Index([   381,    392,   1118,   1644,   1647,   2175,   2183,   2786,
#               2796,   2800,
#             ...
#             250009, 250818, 250886, 250895, 251827, 251865, 251874, 252642,
#             252676, 252685],
#            dtype='int64', length=676)), (('EWR', 'MSN'), Int64Index([   363,   1098,   2156,   2770,   3320,   4782,   5615,   6489,
#               7833,   8625,
#             ...
#             245016, 245922, 246816, 247607, 248323, 249172, 250078, 250959,
#             251936, 252747],
#            dtype='int64', length=280)), (('EWR', 'MSP'), Int64Index([   384,    455,   1015,   1112,   1127,   1543,   1676,   2118,
#               2169,   2854,
#             ...
#             251720, 251816, 251857, 251881, 252278, 252595, 252606, 252691,
#             252695, 253140],
#            dtype='int64', length=1485)), (('EWR', 'MSY'), Int64Index([   506,   1217,   2797,   2900,   3360,   3491,   4055,   4060,
#               4075,   4120,
#             ...
#             251551, 251559, 251836, 252215, 252337, 252405, 252651, 253081,
#             253230, 253296],
#            dtype='int64', length=982)), (('EWR', 'MTJ'), Int64Index([ 2364,  7400, 13015, 17876, 23276, 27921, 32534, 38187, 44059,
#             49814, 55782, 61882],
#            dtype='int64')), (('EWR', 'OKC'), Int64Index([   377,   1643,   2173,   5645,   6513,   7938,   8657,   9501,
#              10281,  11171,
#             ...
#             244026, 244917, 245822, 246709, 247535, 248221, 249052, 249890,
#             251822, 252638],
#            dtype='int64', length=223)), (('EWR', 'OMA'), Int64Index([   364,    370,   1113,   2157,   2179,   2772,   2776,   2789,
#               3330,   3349,
#             ...
#             250059, 250066, 250799, 250946, 250952, 251805, 251923, 251927,
#             252735, 252740],
#            dtype='int64', length=544)), (('EWR', 'ORD'), Int64Index([   536,    573,    669,    690,    710,    714,    715,    718,
#               1243,   1327,
#             ...
#             252467, 253154, 253171, 253201, 253213, 253242, 253281, 253289,
#             253297, 253309],
#            dtype='int64', length=3272)), (('EWR', 'ORF'), Int64Index([   408,   1649,   2810,   2812,   3407,   4779,   5610,   6485,
#               7227,   7857,
#             ...
#             212738, 212764, 215201, 216097, 249089, 249995, 250881, 251860,
#             252670, 252671],
#            dtype='int64', length=211)), (('EWR', 'PBI'), Int64Index([   112,    113,    132,    229,    565,    582,    613,    620,
#                622,    683,
#             ...
#             252422, 252456, 252466, 252901, 253151, 253169, 253195, 253219,
#             253222, 253223],
#            dtype='int64', length=1874)), (('EWR', 'PDX'), Int64Index([   577,    687,   1276,   1760,   1807,   2371,   2374,   2954,
#               3597,   3628,
#             ...
#             246524, 247309, 247316, 247952, 248853, 249682, 250673, 251525,
#             252317, 253268],
#            dtype='int64', length=418)), (('EWR', 'PHL'), Int64Index([21635, 21655, 22482, 22494, 22534, 23368, 24414], dtype='int64')), (('EWR', 'PHX'), Int64Index([   507,    597,    611,    617,    630,    631,    634,    636,
#               1218,   1308,
#             ...
#             252400, 252449, 252835, 253013, 253015, 253082, 253158, 253185,
#             253202, 253252],
#            dtype='int64', length=2002)), (('EWR', 'PIT'), Int64Index([   388,    428,   2835,   3353,   3426,   4068,   4827,   5606,
#               5660,   6480,
#             ...
#             226170, 227035, 230570, 236445, 242297, 249153, 250054, 250942,
#             251919, 252672],
#            dtype='int64', length=353)), (('EWR', 'PVD'), Int64Index([   367,    406,   1101,   1636,   3331,   4040,   4790,   5623,
#               5667,   6496,
#             ...
#             186128, 187064, 188021, 189627, 190515, 206792, 212755, 218838,
#             219541, 243077],
#            dtype='int64', length=169)), (('EWR', 'PWM'), Int64Index([   374,    393,   1119,   1641,   2780,   2801,   3338,   4042,
#               4045,   4079,
#             ...
#             248267, 249094, 249105, 249999, 250010, 250885, 250896, 251864,
#             251875, 252686],
#            dtype='int64', length=392)), (('EWR', 'RDU'), Int64Index([  1096,   1124,   2150,   2187,   2792,   3312,   3400,   3402,
#               4069,   4828,
#             ...
#             236435, 238124, 242288, 244052, 248245, 249090, 249996, 250882,
#             251861, 252673],
#            dtype='int64', length=741)), (('EWR', 'RIC'), Int64Index([   366,    391,    430,   1114,   1152,   1633,   2161,   2206,
#               2765,   2773,
#             ...
#             250888, 250948, 251809, 251814, 251841, 251867, 252629, 252634,
#             252656, 252677],
#            dtype='int64', length=1183)), (('EWR', 'ROC'), Int64Index([  1115,   2793,   3354,   4052,   4057,   4070,   4807,   4815,
#               4829,   5636,
#             ...
#             243087, 244027, 244058, 244919, 244952, 245824, 245856, 246712,
#             246744, 247566],
#            dtype='int64', length=504)), (('EWR', 'RSW'), Int64Index([   161,    567,    586,    675,    688,    870,   1264,   1304,
#               1312,   1377,
#             ...
#             251642, 252335, 252339, 252368, 252403, 252967, 253174, 253199,
#             253265, 253293],
#            dtype='int64', length=1160)), (('EWR', 'SAN'), Int64Index([   594,    624,    735,   1313,   1734,   1789,   2944,   2974,
#               3054,   3539,
#             ...
#             250627, 250650, 251457, 251493, 251521, 252293, 252300, 252375,
#             253184, 253257],
#            dtype='int64', length=884)), (('EWR', 'SAT'), Int64Index([   563,   3633,   4254,   5129,   5840,   6839,   8070,   8913,
#               9861,  10555,
#             ...
#             187839, 188721, 189481, 190458, 248862, 249672, 250676, 251515,
#             252304, 253267],
#            dtype='int64', length=205)), (('EWR', 'SAV'), Int64Index([   390,   2165,   2777,   3332,   3357,   4051,   4806,   6509,
#               7238,   7850,
#             ...
#             249079, 249093, 249984, 249998, 250870, 250884, 251849, 251863,
#             252661, 252675],
#            dtype='int64', length=557)), (('EWR', 'SBN'), Int64Index([248240, 249072, 249977, 250863, 251842, 252657], dtype='int64')), (('EWR', 'SDF'), Int64Index([   355,   1095,   1629,   2152,   2766,   3310,   3315,   4031,
#               4778,   4788,
#             ...
#             249041, 249118, 249880, 250006, 250805, 250911, 251811, 251890,
#             252631, 252682],
#            dtype='int64', length=529)), (('EWR', 'SEA'), Int64Index([    75,     76,    584,    674,    686,    699,    818,    819,
#               1281,   1462,
#             ...
#             251532, 252057, 252058, 252294, 252376, 252430, 252854, 252855,
#             253277, 253285],
#            dtype='int64', length=1364)), (('EWR', 'SFO'), Int64Index([   483,    484,    589,    593,    609,    670,    679,    692,
#                694,    709,
#             ...
#             253231, 253259, 253260, 253261, 253273, 253274, 253290, 253291,
#             253292, 253308],
#            dtype='int64', length=4539)), (('EWR', 'SJU'), Int64Index([    95,    142,    698,    719,    820,   1325,   1352,   1397,
#               1767,   1785,
#             ...
#             249408, 249693, 250302, 250523, 251095, 251534, 251631, 252328,
#             252957, 253286],
#            dtype='int64', length=949)), (('EWR', 'SLC'), Int64Index([   247,   1061,   1606,   2112,   2733,   3375,   3921,   4658,
#               5497,   6444,
#             ...
#             241981, 242742, 243515, 244119, 244898, 245787, 246683, 247534,
#             248175, 248911],
#            dtype='int64', length=285)), (('EWR', 'SNA'), Int64Index([   569,    583,    701,   1280,   1342,   2344,   3024,   3594,
#               3596,   3634,
#             ...
#             250649, 251472, 251475, 251520, 252355, 252362, 252374, 253160,
#             253165, 253272],
#            dtype='int64', length=657)), (('EWR', 'STL'), Int64Index([   357,    398,    400,    411,    508,   1097,   1130,   1132,
#               1219,   1650,
#             ...
#             251884, 251889, 252217, 252218, 252624, 252637, 252687, 252699,
#             253083, 253084],
#            dtype='int64', length=1740)), (('EWR', 'STT'), Int64Index([   712,   1341,   1778,   2354,   2358,   3038,   3609,   4318,
#               5065,   6031,
#             ...
#             184211, 186756, 188756, 189544, 190486, 194910, 201078, 248037,
#             248750, 252360],
#            dtype='int64', length=174)), (('EWR', 'SYR'), Int64Index([   380,   1635,   4050,   4793,   5744,   6594,   7255,   8749,
#               9493,  10264,  11272,  12142,  12845,  14328,  14884,  16085,
#              16991,  17678,  19193,  19889,  20656,  21575,  22362,  23131,
#              24932,  26139,  27002,  27692,  29200,  29927,  30678,  33753,
#              34627,  35432,  36336,  37914,  38630,  39451,  40367,  41257,
#              42146,  43021,  44158,  45556,  46378,  47249,  48301,  49224,
#              49900,  50682,  51706,  52517,  55287,  55957,  56704,  57741,
#              58663,  59433,  60354,  61419,  62095,  62845,  63916,  64722,
#              65606,  66665,  67575,  68237,  68961,  69830, 106970, 151804,
#             158096, 229899, 248247, 248306, 249056, 249121, 250004, 250027,
#             250890, 250913, 251826, 251893, 252680, 252705],
#            dtype='int64')), (('EWR', 'TPA'), Int64Index([   162,    560,    561,    562,    566,    616,    621,    623,
#                871,   1263,
#             ...
#             252379, 252384, 252391, 252407, 252904, 253157, 253186, 253191,
#             253237, 253287],
#            dtype='int64', length=1833)), (('EWR', 'TUL'), Int64Index([   386,   1645,   2788,   4064,   4822,   5654,   6521,   7866,
#               8663,   9512,
#             ...
#             215220, 216119, 217089, 218056, 248236, 249067, 249972, 250858,
#             251837, 252652],
#            dtype='int64', length=201)), (('EWR', 'TVC'), Int64Index([150391, 151021, 151776, 156435, 157328, 158058, 162440, 163319,
#             164108, 168803, 169684, 170484, 176153, 176985, 181761, 182529,
#             183360, 188041, 188794, 189619],
#            dtype='int64')), (('EWR', 'TYS'), Int64Index([   457,   1678,   2229,   2855,   3448,   4139,   5769,   6616,
#               7962,   8773,
#             ...
#             244044, 244937, 245841, 246729, 248250, 249080, 249985, 250871,
#             251850, 252662],
#            dtype='int64', length=238)), (('EWR', 'XNA'), Int64Index([  2791,   3352,   4067,   4826,   5659,   8666,   9516,  11185,
#              12058,  14247,
#             ...
#             240757, 243103, 244946, 245850, 246738, 249088, 249994, 250880,
#             251859, 252669],
#            dtype='int64', length=195)), (('JFK', 'ABQ'), Int64Index([   185,    858,   3890,   4544,   5416,   6246,   7097,   8404,
#               9291,  10099,
#             ...
#             241816, 242474, 243310, 246054, 246947, 247717, 248444, 249302,
#             252066, 252480],
#            dtype='int64', length=278)), (('JFK', 'ACK'), Int64Index([107383, 108212, 108978, 109661, 110507, 111430, 112336, 113191,
#             114004, 114019,
#             ...
#             231598, 232577, 233429, 234317, 235212, 236022, 236623, 237564,
#             241047, 242588],
#            dtype='int64', length=277)), (('JFK', 'ATL'), Int64Index([   250,    264,    272,    273,    320,    966,    967,    982,
#                995,   1546,
#             ...
#             251704, 251755, 251757, 252515, 252562, 252566, 252579, 252586,
#             252590, 252592],
#            dtype='int64', length=1701)), (('JFK', 'AUS'), Int64Index([    18,    146,    165,    256,    758,    872,    888,    972,
#               1441,   1854,
#             ...
#             251207, 251602, 251632, 251655, 251775, 251996, 252621, 252800,
#             252925, 252958],
#            dtype='int64', length=1370)), (('JFK', 'BNA'), Int64Index([   449,   1171,   2221,   2849,   3444,   4134,   4902,   5761,
#               6609,   7953,
#             ...
#             245024, 245930, 246824, 247612, 248329, 249180, 250086, 250967,
#             251944, 252753],
#            dtype='int64', length=284)), (('JFK', 'BOS'), Int64Index([    13,     15,     71,     79,     93,    218,    225,    235,
#                329,    752,
#             ...
#             252784, 252787, 252842, 252849, 252884, 252900, 252920, 252933,
#             252939, 252960],
#            dtype='int64', length=4111)), (('JFK', 'BQN'), Int64Index([   110,    170,    882,    911,   2016,   2599,   3200,   3869,
#               4582,   4588,
#             ...
#             246098, 247056, 247793, 247804, 248525, 249381, 250279, 251209,
#             251604, 252927],
#            dtype='int64', length=535)), (('JFK', 'BTV'), Int64Index([    82,    219,    221,    234,    840,    841,    842,   1483,
#               1486,   1932,
#             ...
#             250321, 251107, 251113, 251155, 251644, 251650, 252090, 252873,
#             252969, 252975],
#            dtype='int64', length=1004)), (('JFK', 'BUF'), Int64Index([    83,    111,    206,    209,    216,    222,    227,    832,
#                836,    846,
#             ...
#             251661, 251663, 251665, 252916, 252979, 252981, 252984, 252986,
#             252988, 252990],
#            dtype='int64', length=2164)), (('JFK', 'BUR'), Int64Index([   197,    860,   2017,   3887,   4577,   5378,   6318,   7037,
#               8454,   9301,
#             ...
#             245182, 246178, 246990, 247758, 248483, 249340, 250242, 251169,
#             252104, 252887],
#            dtype='int64', length=289)), (('JFK', 'BWI'), Int64Index([   454,   1174,   2226,   2853,   4138,   5766,   6614,   7957,
#               8770,   9616,
#             ...
#             245028, 245934, 246828, 247616, 248333, 249184, 250090, 250971,
#             251948, 252757],
#            dtype='int64', length=282)), (('JFK', 'CHS'), Int64Index([    77,    211,    829,    833,   1487,   1921,   1942,   2625,
#               3181,   3851,
#             ...
#             249407, 249413, 250301, 250307, 251094, 251099, 251630, 251636,
#             252956, 252962],
#            dtype='int64', length=587)), (('JFK', 'CLE'), Int64Index([   447,   1169,   2219,   2848,   3442,   4900,   5758,   6606,
#               7950,   8762,
#             ...
#             245022, 245928, 246822, 247610, 248327, 249178, 250084, 250965,
#             251942, 252751],
#            dtype='int64', length=280)), (('JFK', 'CLT'), Int64Index([   231,    233,    641,    648,    649,    650,    738,    837,
#                839,   1408,
#             ...
#             252139, 252194, 252196, 252870, 252945, 252991, 252993, 253022,
#             253032, 253035],
#            dtype='int64', length=2272)), (('JFK', 'CMH'), Int64Index([   446,    531,   1166,   1717,   2218,   2309,   2847,   2917,
#               3440,   3512,
#             ...
#             249174, 249593, 250080, 250487, 250961, 251370, 251938, 252265,
#             252749, 253131],
#            dtype='int64', length=576)), (('JFK', 'CVG'), Int64Index([   451,   2223,   2850,   3446,   4904,   5763,   6611,   8767,
#               9614,  10427,
#             ...
#             245027, 245933, 246827, 247615, 248332, 249183, 250089, 250970,
#             251947, 252756],
#            dtype='int64', length=282)), (('JFK', 'DCA'), Int64Index([   460,    469,    472,    526,    538,   1176,   1183,   1184,
#               1234,   1712,
#             ...
#             251964, 252112, 252256, 252276, 252760, 252770, 252772, 252942,
#             253122, 253139],
#            dtype='int64', length=1686)), (('JFK', 'DEN'), Int64Index([    97,    316,    937,   1046,   2098,   3235,   3994,   4699,
#               5322,   5515,
#             ...
#             248179, 248448, 249009, 249306, 249940, 250776, 251785, 252070,
#             252484, 252528],
#            dtype='int64', length=579)), (('JFK', 'DFW'), Int64Index([   240,    948,   1539,   2022,   2621,   3229,   3901,   4641,
#               5462,   6338,
#             ...
#             248420, 249222, 249277, 250128, 250183, 251009, 251064, 251986,
#             252041, 252792],
#            dtype='int64', length=474)), (('JFK', 'DTW'), Int64Index([   305,   1035,   1586,   2085,   2711,   3295,   3966,   4756,
#               5581,   6378,
#             ...
#             244845, 245776, 246623, 247474, 248202, 249031, 249961, 250731,
#             251799, 252548],
#            dtype='int64', length=198)), (('JFK', 'EGE'), Int64Index([   73,   815,  1901,  2518,  3166,  3827,  4502,  5308,  6184,
#              7011,  7555,  8324,  9190, 10016, 10834, 11711, 12572, 13163,
#             13900, 15145, 15696, 16555, 17410, 17993, 18772, 19618, 20387,
#             22867, 23450, 24138, 24659, 25336, 25726, 26564, 27426, 28011,
#             28763, 29623, 30432, 31135, 31463, 32137, 32705, 33454, 34358,
#             35139, 36028, 36921, 37660, 38329, 39152, 40074, 40978, 41857,
#             42776, 43675, 44335, 45057, 45743, 46617, 47516, 48435, 49335,
#             50058, 50910, 51838, 52757, 53638, 54504, 55400, 56116, 56960,
#             57870, 58789, 59703, 60633, 61533, 62256, 63117, 64047, 64965,
#             65869, 66799, 67686, 68398],
#            dtype='int64')), (('JFK', 'FLL'), Int64Index([   101,    105,    122,    123,    127,    128,    138,    172,
#                174,    184,
#             ...
#             252097, 252475, 252519, 252532, 252866, 252880, 252908, 252952,
#             252968, 252972],
#            dtype='int64', length=3258)), (('JFK', 'HNL'), Int64Index([   444,   1164,   1673,   2216,   2845,   3438,   4129,   4895,
#               5753,   6602,
#             ...
#             241673, 242350, 243176, 245920, 246814, 247605, 248321, 249170,
#             251933, 252745],
#            dtype='int64', length=260)), (('JFK', 'HOU'), Int64Index([    92,    207,    825,   1476,   1940,   2528,   2541,   3835,
#               4592,   4616,
#             ...
#             249329, 249369, 250231, 250268, 251158, 251197, 251592, 252093,
#             252876, 252915],
#            dtype='int64', length=570)), (('JFK', 'HYA'), Int64Index([143413, 144317, 145250, 145932, 146913, 147818, 148665, 149398,
#             150375, 150743, 151486, 152368, 153341, 154198, 155144, 156143,
#             157061, 158046, 158648, 159514, 161193, 162134, 163133, 163838,
#             164720, 165773, 166629, 167533, 168477, 169419, 170266, 171066,
#             172034, 172993, 173927, 174825, 175732, 176467, 177349, 178299,
#             179255, 180210, 181169, 182110, 182843, 183721, 184673, 185562,
#             186477, 187438, 188383, 189102, 189981, 190936, 191861, 192789,
#             193727, 194648, 195339, 196194, 197132, 198061, 199002, 199948,
#             200879, 201548, 202286, 203170, 204071, 204914, 205757, 206580,
#             207208, 208029, 208939],
#            dtype='int64')), (('JFK', 'IAD'), Int64Index([    84,    212,    552,    554,    834,    851,   1478,   1929,
#               2323,   2324,
#             ...
#             249410, 249417, 250304, 250311, 251097, 251103, 251633, 251640,
#             252959, 252965],
#            dtype='int64', length=1604)), (('JFK', 'IAH'), Int64Index([17, 757, 1440, 1853, 2464, 3116, 3772], dtype='int64')), (('JFK', 'IND'), Int64Index([   558,   2230,   4141,   4909,   5772,   6619,   7965,   8777,
#               9619,  10436,
#             ...
#             245033, 245940, 246834, 247621, 248339, 249190, 250096, 250977,
#             251954, 252763],
#            dtype='int64', length=278)), (('JFK', 'JAC'), Int64Index([2089], dtype='int64')), (('JFK', 'JAX'), Int64Index([    89,     90,    226,    828,    835,    844,   1481,   1485,
#               2633,   3176,
#             ...
#             250317, 251109, 251179, 251196, 251573, 251591, 251646, 252896,
#             252914, 252971],
#            dtype='int64', length=843)), (('JFK', 'LAS'), Int64Index([    59,    116,    120,    151,    238,    248,    255,    326,
#                486,    801,
#             ...
#             252521, 252556, 252593, 252608, 252791, 252831, 252890, 252909,
#             252919, 253055],
#            dtype='int64', length=3355)), (('JFK', 'LAX'), Int64Index([     1,      2,      3,      5,      7,      8,     14,    156,
#                158,    163,
#             ...
#             252910, 253058, 253059, 253060, 253061, 253062, 253227, 253228,
#             253238, 253249],
#            dtype='int64', length=10208)), (('JFK', 'LGB'), Int64Index([   114,    155,    906,    907,   1500,   1997,   2578,   2614,
#               3215,   3898,
#             ...
#             249322, 249392, 250224, 250289, 251082, 251151, 251615, 252086,
#             252869, 252938],
#            dtype='int64', length=526)), (('JFK', 'MCO'), Int64Index([    68,     74,     94,    115,    117,    119,    121,    148,
#                153,    169,
#             ...
#             252846, 252853, 252863, 252877, 252897, 252906, 252929, 252949,
#             252976, 252978],
#            dtype='int64', length=4467)), (('JFK', 'MIA'), Int64Index([     9,     38,     64,     65,     69,    260,    322,    350,
#                749,    777,
#             ...
#             252517, 252575, 252616, 252834, 252836, 252840, 252841, 252844,
#             252848, 252856],
#            dtype='int64', length=2750)), (('JFK', 'MSP'), Int64Index([  3252,   4007,   4713,   5530,   6417,   8500,   9363,  10177,
#              11010,  11887,
#             ...
#             249958, 250695, 250702, 250792, 251697, 251702, 251796, 252545,
#             252583, 252588],
#            dtype='int64', length=458)), (('JFK', 'MSY'), Int64Index([   208,    214,    228,    843,    847,   1488,   1918,   1935,
#               2538,   3844,
#             ...
#             251582, 251590, 251601, 251707, 251797, 252546, 252594, 252905,
#             252913, 252924],
#            dtype='int64', length=908)), (('JFK', 'MVY'), Int64Index([113186, 114039, 114894, 115505, 116172, 117096, 117918, 118760,
#             119959, 120568,
#             ...
#             229316, 231002, 231606, 234326, 235220, 236031, 236729, 237572,
#             241042, 242582],
#            dtype='int64', length=159)), (('JFK', 'OAK'), Int64Index([   188,    918,   1955,   5403,   6254,   7683,   8418,  10916,
#              11791,  13250,
#             ...
#             243327, 244317, 245159, 246152, 246964, 247734, 248458, 249315,
#             252080, 252862],
#            dtype='int64', length=247)), (('JFK', 'ORD'), Int64Index([    16,    143,    237,    756,    932,   1475,   1529,   1852,
#               1931,   2011,
#             ...
#             251137, 251213, 251608, 251984, 252002, 252071, 252485, 252790,
#             252804, 252931],
#            dtype='int64', length=1265)), (('JFK', 'ORF'), Int64Index([   459,   2231,   2857,   4910,   5773,   6620,   7966,   8778,
#               9620,  10437,
#             ...
#             245031, 245938, 246832, 247619, 248337, 249188, 250094, 250972,
#             251949, 252758],
#            dtype='int64', length=282)), (('JFK', 'PBI'), Int64Index([    78,     96,    102,    109,    139,    177,    193,    855,
#                874,    884,
#             ...
#             251193, 251204, 251571, 251579, 251588, 251599, 252894, 252902,
#             252911, 252922],
#            dtype='int64', length=1362)), (('JFK', 'PDX'), Int64Index([   204,    251,    975,   1067,   1537,   1610,   1986,   2043,
#               2596,   2740,
#             ...
#             247818, 248182, 248549, 249405, 249943, 250843, 251628, 251788,
#             252574, 252954],
#            dtype='int64', length=725)), (('JFK', 'PHL'), Int64Index([103388], dtype='int64')), (('JFK', 'PHX'), Int64Index([   130,    319,    632,    633,    639,    739,    864,   1020,
#               1364,   1400,
#             ...
#             252077, 252114, 252116, 252198, 252200, 252531, 252859, 252995,
#             253014, 253016],
#            dtype='int64', length=1784)), (('JFK', 'PIT'), Int64Index([   461,   1679,   2233,   2859,   3450,   4911,   5775,   6622,
#               7968,   8780,
#             ...
#             245030, 245937, 246831, 247618, 248336, 249187, 250093, 250975,
#             251952, 252761],
#            dtype='int64', length=384)), (('JFK', 'PSE'), Int64Index([   125,    919,   1514,   2591,   3896,   4630,   5455,   6252,
#               7616,   8446,
#             ...
#             245212, 246084, 247043, 247790, 248519, 249375, 250274, 251203,
#             251598, 252921],
#            dtype='int64', length=289)), (('JFK', 'PSP'), Int64Index([ 2263,  7308, 12912, 17782, 23197, 27795, 32461, 38082, 43946,
#             49626, 55690, 61789, 67943, 73952, 80000, 85855, 92016],
#            dtype='int64')), (('JFK', 'PWM'), Int64Index([    85,    224,    232,    827,    838,   1474,   1907,   1909,
#               1941,   2630,
#             ...
#             250223, 250237, 251138, 251150, 251164, 252072, 252099, 252486,
#             252868, 252882],
#            dtype='int64', length=1076)), (('JFK', 'RDU'), Int64Index([    87,    220,    223,    466,    467,    468,    470,    826,
#                849,   1181,
#             ...
#             251955, 251963, 252255, 252259, 252764, 252771, 252930, 252950,
#             253121, 253125],
#            dtype='int64', length=1770)), (('JFK', 'ROC'), Int64Index([    98,    213,    215,    845,    890,   1489,   1919,   1937,
#               1994,   2539,
#             ...
#             251181, 251191, 251575, 251584, 251637, 252095, 252878, 252898,
#             252907, 252963],
#            dtype='int64', length=1036)), (('JFK', 'RSW'), Int64Index([    81,     88,    149,    154,    822,    831,    876,    905,
#               1470,   1507,
#             ...
#             250320, 251087, 251112, 251217, 251613, 251621, 251649, 252936,
#             252946, 252974],
#            dtype='int64', length=856)), (('JFK', 'SAN'), Int64Index([   100,    129,    241,    312,    821,   1056,   1494,   1587,
#               1602,   2023,
#             ...
#             251701, 251705, 251979, 252069, 252082, 252483, 252587, 252591,
#             252786, 252864],
#            dtype='int64', length=1402)), (('JFK', 'SAT'), Int64Index([  1027,   1582,   2035,   2645,  44559,  45191,  46030,  46877,
#              47691,  49577,
#             ...
#             244812, 245740, 246667, 247510, 248163, 248905, 249928, 250765,
#             251773, 252619],
#            dtype='int64', length=242)), (('JFK', 'SAV'), Int64Index([ 31144,  31153,  31756,  31757,  32145,  32146,  32722,  32723,
#              33480,  33481,
#             ...
#             249382, 249395, 250280, 250291, 251084, 251210, 251605, 251617,
#             252928, 252941],
#            dtype='int64', length=514)), (('JFK', 'SEA'), Int64Index([    10,    135,    266,    267,    902,    970,    986,    987,
#               1436,   1551,
#             ...
#             251690, 251691, 251989, 252091, 252557, 252572, 252576, 252577,
#             252794, 252874],
#            dtype='int64', length=1815)), (('JFK', 'SFO'), Int64Index([    12,    190,    194,    196,    239,    242,    252,    262,
#                263,    265,
#             ...
#             253047, 253054, 253056, 253057, 253207, 253224, 253233, 253234,
#             253235, 253239],
#            dtype='int64', length=7368)), (('JFK', 'SJC'), Int64Index([   166,    912,   1992,   2616,   5391,   6265,   7605,   8392,
#              10864,  11801,
#             ...
#             244364, 245205, 246076, 247035, 247782, 248509, 249366, 251194,
#             251589, 252912],
#            dtype='int64', length=252)), (('JFK', 'SJU'), Int64Index([    35,     55,     99,    140,    147,    175,    192,    198,
#                201,    202,
#             ...
#             252526, 252537, 252578, 252793, 252889, 252917, 252926, 252953,
#             252964, 252966],
#            dtype='int64', length=4027)), (('JFK', 'SLC'), Int64Index([   176,    261,    274,    325,    328,    857,    979,    990,
#                996,   1062,
#             ...
#             250822, 251134, 251668, 251694, 251698, 252067, 252481, 252552,
#             252580, 252584],
#            dtype='int64', length=1706)), (('JFK', 'SMF'), Int64Index([   152,    863,   2003,   5394,   6320,   7646,   8441,  10915,
#              11793,  13239,
#             ...
#             242489, 243325, 244315, 245157, 246150, 246962, 247732, 248456,
#             252078, 252860],
#            dtype='int64', length=246)), (('JFK', 'SRQ'), Int64Index([   157,    925,   1974,   2584,   3211,   4562,   5440,   6285,
#               7074,   7643,
#             ...
#             245158, 246151, 246963, 247733, 248457, 249314, 250217, 251144,
#             252079, 252861],
#            dtype='int64', length=370)), (('JFK', 'STT'), Int64Index([    33,    269,    773,    989,   1864,   2050,   2477,   2670,
#               3124,   3257,
#             ...
#             243481, 245309, 245693, 246596, 247446, 248089, 248968, 249852,
#             251695, 252581],
#            dtype='int64', length=450)), (('JFK', 'SYR'), Int64Index([    86,    210,    217,    850,    854,   1469,   1480,   1911,
#               1917,   1927,
#             ...
#             250323, 251115, 251139, 251165, 251652, 252073, 252100, 252487,
#             252883, 252977],
#            dtype='int64', length=937)), (('JFK', 'TPA'), Int64Index([   126,    133,    171,    191,    195,    315,    452,    453,
#                881,    883,
#             ...
#             251768, 251786, 252089, 252102, 252529, 252614, 252872, 252885,
#             252934, 252940],
#            dtype='int64', length=2019)), (('LGA', 'AGS'), Int64Index([74656, 75539, 79126], dtype='int64')), (('LGA', 'ATL'), Int64Index([   244,    246,    282,    284,    285,    293,    298,    308,
#                324,    331,
#             ...
#             252603, 252605, 252612, 252620, 253085, 253086, 253087, 253088,
#             253089, 253090],
#            dtype='int64', length=6925)), (('LGA', 'AVL'), Int64Index([151089, 195926], dtype='int64')), (('LGA', 'BGR'), Int64Index([   420,   1143,   2200,   2824,   4105,   4871,   5715,   6570,
#               7916,   8721,
#             ...
#             213555, 218850, 219607, 224550, 225280, 227112, 229939, 235793,
#             241648, 247583],
#            dtype='int64', length=274)), (('LGA', 'BHM'), Int64Index([   415,   1654,   4862,   5706,   7905,   8712,   9561,  10326,
#              11234,  12103,
#             ...
#             112800, 116660, 118409, 119263, 120169, 121896, 122795, 123667,
#             127186, 133073],
#            dtype='int64', length=124)), (('LGA', 'BNA'), Int64Index([   424,    426,    510,    511,    527,    528,    540,    545,
#               1138,   1151,
#             ...
#             252285, 252707, 252773, 253091, 253092, 253093, 253124, 253132,
#             253135, 253148],
#            dtype='int64', length=2600)), (('LGA', 'BOS'), Int64Index([  1427,   1428,   1792,   3090,   3091,   3718,   3719,   3720,
#               3721,   3722,
#             ...
#             253037, 253038, 253039, 253040, 253041, 253042, 253043, 253044,
#             253045, 253046],
#            dtype='int64', length=3230)), (('LGA', 'BTV'), Int64Index([  1146,   1147,   1148,   2201,   2203,   2205,   2827,   3422,
#               4112,   4880,
#             ...
#             243131, 244080, 244974, 245879, 246768, 248278, 249123, 250029,
#             251894, 252706],
#            dtype='int64', length=229)), (('LGA', 'BUF'), Int64Index([   416,   1139,   2198,   2821,  12859,  35558,  36457,  37250,
#              39585,  40502,
#             ...
#             244085, 244979, 245884, 246773, 248283, 249128, 250034, 250920,
#             251898, 252711],
#            dtype='int64', length=169)), (('LGA', 'BZN'), Int64Index([138991, 145557, 150988, 157238, 163225, 169606, 175821, 182203,
#             188523, 195006, 201252, 206723, 212683, 218660, 224434],
#            dtype='int64')), (('LGA', 'CAE'), Int64Index([  1657,   2826,   4863,   5707,   6562,   7906,   8713,   9562,
#              10327,  11235,
#             ...
#             249135, 249143, 250040, 250047, 250926, 250933, 251905, 251912,
#             252722, 252727],
#            dtype='int64', length=382)), (('LGA', 'CAK'), Int64Index([   438,    442,   1159,   1667,   1670,   2213,   2841,   3432,
#               3436,   4124,
#             ...
#             250453, 251315, 251316, 251317, 252228, 252229, 252230, 253094,
#             253095, 253096],
#            dtype='int64', length=708)), (('LGA', 'CHO'), Int64Index([ 45631,  47379,  48292,  49214,  50774,  51692,  52622,  53504,
#              54373,  55277,
#             ...
#             249129, 249182, 250035, 250088, 250921, 250969, 251900, 251946,
#             252713, 252755],
#            dtype='int64', length=329)), (('LGA', 'CHS'), Int64Index([   418,   1141,   1256,   2823,   7269,  17692,  27705,  33867,
#              34096,  34863,
#             ...
#             249116, 249147, 249610, 250023, 250503, 250909, 251888, 252282,
#             252698, 253144],
#            dtype='int64', length=574)), (('LGA', 'CLE'), Int64Index([   356,    463,    529,    548,    571,   1178,   1249,   1270,
#               1642,   1656,
#             ...
#             252284, 252630, 252636, 252678, 252679, 252710, 252717, 252724,
#             252744, 253146],
#            dtype='int64', length=2111)), (('LGA', 'CLT'), Int64Index([   422,    445,    471,    557,    637,    642,    643,    644,
#                647,    651,
#             ...
#             252140, 252141, 252197, 252994, 253020, 253025, 253027, 253028,
#             253029, 253036],
#            dtype='int64', length=3431)), (('LGA', 'CMH'), Int64Index([   464,    473,    474,    542,   1179,   1185,   1187,   1236,
#               1684,   1713,
#             ...
#             251957, 251960, 251967, 252264, 252271, 252754, 252766, 252768,
#             252775, 253130],
#            dtype='int64', length=1816)), (('LGA', 'CVG'), Int64Index([   423,  12855,  23776,  87381, 125031, 125516, 126469, 127208,
#             128037, 128041, 128961, 129866, 131602, 132386, 133928, 134878,
#             135837, 136778, 137718, 138679, 140299, 141247, 142205, 143066,
#             143964, 144998, 147571, 148184, 151906, 152814, 153719, 154634,
#             155600, 156554, 158196, 160666, 161629, 162563, 164226, 165166,
#             166126, 167962, 168924, 170594, 171482, 172440, 173395, 174354,
#             175496, 177098, 178050, 179003, 179956, 180914, 181865, 183474,
#             184427, 186232, 187189, 188146, 189733, 190685, 191615, 192540,
#             193479, 194419, 195957, 196875, 197813, 198752, 199700, 200652,
#             202040, 202772, 206114, 250928, 251907, 252721],
#            dtype='int64')), (('LGA', 'DAL'), Int64Index([250421, 250422, 250423, 251247, 251248, 251249, 251250, 252190,
#             252191, 252192, 252193, 253063, 253064, 253065, 253066],
#            dtype='int64')), (('LGA', 'DAY'), Int64Index([ 70047,  70059,  70477,  70947,  70959,  71373,  71846,  71858,
#              72243,  72760,
#             ...
#             249590, 249608, 250484, 250501, 251367, 251385, 252262, 252280,
#             253128, 253142],
#            dtype='int64', length=490)), (('LGA', 'DCA'), Int64Index([   658,    659,    660,   1429,   1430,   1431,   1432,   1793,
#               1794,   1795,
#             ...
#             253002, 253003, 253004, 253005, 253006, 253007, 253008, 253009,
#             253010, 253011],
#            dtype='int64', length=3753)), (('LGA', 'DEN'), Int64Index([   279,    349,    435,    436,    512,    513,    610,    615,
#                663,    695,
#             ...
#             252547, 252602, 252743, 253097, 253098, 253167, 253210, 253218,
#             253232, 253245],
#            dtype='int64', length=2939)), (('LGA', 'DFW'), Int64Index([    39,     41,     44,     45,     46,     47,     48,     49,
#                 50,     51,
#             ...
#             252819, 252820, 252821, 252822, 252823, 252824, 252825, 252826,
#             252827, 252843],
#            dtype='int64', length=3789)), (('LGA', 'DSM'), Int64Index([2745], dtype='int64')), (('LGA', 'DTW'), Int64Index([   245,    280,    287,    307,    477,    533,    535,    539,
#                549,    953,
#             ...
#             252534, 252550, 252600, 252604, 252611, 252618, 253123, 253137,
#             253143, 253315],
#            dtype='int64', length=3663)), (('LGA', 'EYW'), Int64Index([  1045,   1595,   2097,   2721,  32384,  37911,  43875,  49596,
#              55646,  62037,  68180,  74183,  80228,  86160,  91769,  97629,
#             103431, 109184, 115131, 120811, 126811, 132739, 139322, 145551,
#             150881, 157251, 163238, 169565, 175899, 182216, 188535, 194949],
#            dtype='int64')), (('LGA', 'FLL'), Int64Index([   104,    107,    144,    150,    173,    181,    292,    303,
#                338,    341,
#             ...
#             252496, 252502, 252518, 252543, 252875, 252888, 252937, 252948,
#             252955, 252961],
#            dtype='int64', length=3304)), (('LGA', 'GRR'), Int64Index([  3420,   4108,   4876,   5724,   6579,   7923,   8730,   9577,
#              10345,  11252,
#             ...
#             192538, 193477, 194416, 195954, 196872, 197810, 198750, 199697,
#             200649, 202696],
#            dtype='int64', length=266)), (('LGA', 'GSO'), Int64Index([  1144,   2193,   2825,   4099,   4860,   5704,   7903,   8710,
#               9559,  10324,
#             ...
#             250989, 251368, 251903, 251953, 251966, 252263, 252718, 252762,
#             252774, 253129],
#            dtype='int64', length=868)), (('LGA', 'GSP'), Int64Index([195107, 201320, 202677], dtype='int64')), (('LGA', 'HOU'), Int64Index([   514,    515,   1225,   1226,   1705,   2276,   2907,   2908,
#               3500,   3501,
#             ...
#             251322, 251323, 252233, 252234, 252235, 252236, 253099, 253100,
#             253101, 253102],
#            dtype='int64', length=905)), (('LGA', 'IAD'), Int64Index([   427,    553,    555,    556,   1257,   1258,   1259,   2207,
#               2831,   2935,
#             ...
#             249156, 249157, 249872, 250058, 250798, 250945, 251804, 251922,
#             252625, 252734],
#            dtype='int64', length=1091)), (('LGA', 'IAH'), Int64Index([   575,    592,    595,    603,    681,    704,   1265,   1268,
#               1273,   1285,
#             ...
#             252428, 253152, 253153, 253162, 253221, 253255, 253288, 253300,
#             253306, 253312],
#            dtype='int64', length=2346)), (('LGA', 'ILM'), Int64Index([  1136,   1651,  70444,  71339,  72207,  73128,  74685,  75563,
#              76503,  77339,
#             ...
#             220517, 221391, 222247, 223074, 223903, 224580, 225331, 226198,
#             227063, 227393],
#            dtype='int64', length=223)), (('LGA', 'IND'), Int64Index([  1133,  45615,  46463,  47348,  48263,  49185,  51664,  52593,
#              53477,  54347,  55247,  57705,  58620,  59536,  60467,  61381,
#              63873,  64799,  65704,  66626,  67536,  69942,  70401,  71298,
#              72165,  73084,  73874,  75525,  76467,  77303,  78080,  79111,
#              79836,  81546,  82392,  83203,  84135,  84940,  87366,  88339,
#              89273,  90221,  91132,  91903,  93554,  94425,  95181,  96170,
#             202036],
#            dtype='int64')), (('LGA', 'JAX'), Int64Index([  7917,  14301,  18371,  28368,  45626,  46477,  47361,  48277,
#              49199,  50761,  51678,  52607,  53488,  54360,  55261,  56816,
#              58634,  59549,  60480,  61395,  62926,  63887,  64812,  65717,
#              66640,  67550,  69019,  69957,  73878,  79840,  91907,  97068,
#              98621,  99576, 100335, 101261, 102149, 103006, 104409, 105250,
#             106076, 106930, 107788, 108683, 110125, 110945, 111868, 112812,
#             113639, 117583, 118421, 119275, 120180, 121911, 122814, 123683,
#             124575, 146600, 148168, 151094, 158192, 164222, 170591, 177087,
#             183463, 189722, 217204],
#            dtype='int64')), (('LGA', 'LIT'), Int64Index([ 70479,  71375,  72245,  73161,  73931,  74722,  75597,  76539,
#              77376,  78161,
#             ...
#             245466, 246337, 247222, 247931, 248693, 249582, 250476, 251359,
#             252254, 253120],
#            dtype='int64', length=204)), (('LGA', 'MCI'), Int64Index([ 23781,  33863,  35539,  36439,  37237,  39566,  40482,  42265,
#              43147,  44966,
#             ...
#             250504, 250934, 250936, 251387, 251913, 251915, 252283, 252728,
#             252730, 253145],
#            dtype='int64', length=406)), (('LGA', 'MCO'), Int64Index([   131,    160,    187,    203,    304,    309,    333,    339,
#                342,    348,
#             ...
#             252490, 252494, 252497, 252615, 252622, 252865, 252879, 252899,
#             252943, 252951],
#            dtype='int64', length=3078)), (('LGA', 'MDW'), Int64Index([   516,    517,    518,    519,   1227,   1228,   1706,   1707,
#               1708,   2277,
#             ...
#             252243, 252244, 253103, 253104, 253105, 253106, 253107, 253108,
#             253109, 253110],
#            dtype='int64', length=1937)), (('LGA', 'MEM'), Int64Index([401, 1125, 2195], dtype='int64')), (('LGA', 'MHT'), Int64Index([  1140,   2822,   3412,   4098,   4858,   4859,   5701,   5702,
#               6559,   6560,
#             ...
#             244991, 245893, 246786, 247587, 248293, 249140, 250044, 250930,
#             251909, 252725],
#            dtype='int64', length=146)), (('LGA', 'MIA'), Int64Index([    36,     37,     40,     57,     58,     61,     62,     66,
#                 67,     70,
#             ...
#             252609, 252813, 252833, 252838, 252839, 252845, 252847, 252850,
#             252851, 253021],
#            dtype='int64', length=5084)), (('LGA', 'MKE'), Int64Index([   520,    521,    522,   1229,   1230,   1231,   1709,   1710,
#               2281,   2282,
#             ...
#             251334, 251335, 252245, 252246, 252247, 252248, 253111, 253112,
#             253113, 253114],
#            dtype='int64', length=1176)), (('LGA', 'MSN'), Int64Index([  1142,   1658,   2828,   3416,   3423,   4870,   4881,   5714,
#               5729,   6569,
#             ...
#             243154, 244103, 245898, 246791, 248298, 249145, 250049, 250935,
#             251914, 252729],
#            dtype='int64', length=188)), (('LGA', 'MSP'), Int64Index([   295,    301,    306,    344,    537,    543,    550,    958,
#               1016,   1025,
#             ...
#             251764, 251771, 251777, 252492, 252499, 252504, 252512, 252520,
#             252610, 252617],
#            dtype='int64', length=2220)), (('LGA', 'MSY'), Int64Index([   281,    317,    340,   1048,   1069,   1070,   1615,   1616,
#               2125,   2196,
#             ...
#             247480, 247481, 248063, 248127, 248920, 248943, 249828, 250825,
#             251671, 252555],
#            dtype='int64', length=738)), (('LGA', 'MYR'), Int64Index([ 49927,  55984,  62123,  68266, 151090, 157410, 163399, 169765,
#             176233, 182609, 188871],
#            dtype='int64')), (('LGA', 'OMA'), Int64Index([  1659,   4113,   4883,   5731,   6585,   7928,   8737,   9582,
#              10399,  11259,  12128,  14316,  15397,  16073,  18382,  19182,
#              22349,  23772,  24975,  26964,  28360,  29165,  29977,  30742,
#              33874,  34682,  35549,  36447,  38723,  39575,  40492,  41379,
#              42275,  43157, 148190, 202669, 203568, 204433, 205279, 206125,
#             207675, 208467, 209337, 210232, 211128, 212045, 213559, 214426,
#             215330, 216224, 217195, 218207, 219611, 220484, 221360, 222216,
#             223045, 223868, 225284, 226166, 227032, 227375, 228252, 229127,
#             231424, 232332, 233183, 234065, 234961, 236481, 237320, 238202,
#             239051, 239928, 240818, 242336, 243161, 244130, 245000, 245905,
#             246798, 248304, 249152, 250053, 250940, 251918, 252733],
#            dtype='int64')), (('LGA', 'ORD'), Int64Index([    20,     21,     22,     23,     24,     25,     27,     28,
#                 29,     30,
#             ...
#             253149, 253179, 253211, 253217, 253220, 253229, 253241, 253246,
#             253247, 253250],
#            dtype='int64', length=7052)), (('LGA', 'ORF'), Int64Index([  3424,   4882,   5716,   5730,   6571,   6584,   7918,   8722,
#               8736,   9570,
#             ...
#             251374, 251384, 251906, 251924, 252269, 252279, 252720, 252736,
#             253134, 253141],
#            dtype='int64', length=1014)), (('LGA', 'PBI'), Int64Index([     4,     54,    103,    106,    136,    276,    277,    288,
#                289,    743,
#             ...
#             251784, 251787, 252527, 252530, 252536, 252607, 252895, 252903,
#             252923, 252947],
#            dtype='int64', length=2307)), (('LGA', 'PHL'), Int64Index([   652,    656,   1421,   1425,   2436,   3075,   3082,   3088,
#               3715,   4376,
#             ...
#             249449, 249460, 250343, 250358, 251225, 251272, 252138, 252199,
#             253012, 253034],
#            dtype='int64', length=702)), (('LGA', 'PIT'), Int64Index([  1150,   1660,   5703,   6561,   7261,   8709,   9558,  10323,
#              11231,  12101,
#             ...
#             245907, 246781, 246800, 248289, 248308, 249122, 249136, 250022,
#             250908, 251887],
#            dtype='int64', length=262)), (('LGA', 'PWM'), Int64Index([   419,   1149,  23768,  31657,  32328,  32855,  33620,  33864,
#              34533,  35345,
#             ...
#             145748, 146624, 148187, 157408, 163397, 169763, 176010, 182354,
#             188656, 206825],
#            dtype='int64', length=131)), (('LGA', 'RDU'), Int64Index([   462,    475,    478,    530,    534,    541,    544,   1177,
#               1186,   1189,
#             ...
#             252472, 252719, 252765, 252769, 253118, 253119, 253126, 253127,
#             253136, 253314],
#            dtype='int64', length=2499)), (('LGA', 'RIC'), Int64Index([   551,   1145,   1661,   2829,   3415,   4101,   4103,   4106,
#               4864,   4872,
#             ...
#             249142, 249150, 250046, 250052, 250932, 250938, 251911, 251917,
#             252726, 252732],
#            dtype='int64', length=1135)), (('LGA', 'ROA'), Int64Index([ 70446,  71341,  72209,  73130,  74687,  76505,  77341,  78127,
#              79155,  80713,
#             ...
#             195131, 195971, 197838, 198778, 199723, 200674, 201344, 202057,
#             202710, 203603],
#            dtype='int64', length=125)), (('LGA', 'ROC'), Int64Index([   421,    425,   4104,   4869,   5713,   6568,   6778,   7914,
#               8719,   9568,
#             ...
#             244976, 245881, 246770, 247592, 248280, 249125, 250031, 250917,
#             251895, 252708],
#            dtype='int64', length=254)), (('LGA', 'RSW'), Int64Index([   145,    314,    336,    347,    869,    959,   1044,   1053,
#               1054,   1515,
#             ...
#             245254, 246127, 247082, 247832, 248566, 249422, 250316, 251108,
#             251645, 252970],
#            dtype='int64', length=569)), (('LGA', 'SAV'), Int64Index([  5735,   6587,   8741,   9585,  10403,  11263,  12132,  14320,
#              14913,  16076,
#             ...
#             250042, 250051, 250915, 250937, 250939, 251886, 251916, 252697,
#             252723, 252731],
#            dtype='int64', length=368)), (('LGA', 'SBN'), Int64Index([200636, 234958], dtype='int64')), (('LGA', 'SDF'), Int64Index([ 70042,  70052,  70941,  70943,  70953,  71839,  71841,  71852,
#              72755,  72766,
#             ...
#             250497, 250687, 251379, 251380, 251570, 252274, 252275, 252474,
#             253138, 253316],
#            dtype='int64', length=542)), (('LGA', 'SRQ'), Int64Index([   159,    275,   1010,   1601,   2028,   2523,   2637,   3888,
#               4570,   5452,
#             ...
#             245189, 246186, 246998, 247765, 248490, 249347, 250249, 251176,
#             252111, 252893],
#            dtype='int64', length=496)), (('LGA', 'STL'), Int64Index([   417,    448,    450,    523,    524,   1167,   1170,   1172,
#               1232,   1233,
#             ...
#             251950, 252249, 252250, 252251, 252750, 252752, 252759, 253115,
#             253116, 253117],
#            dtype='int64', length=2065)), (('LGA', 'SYR'), Int64Index([  4102,   4866,   5710,   5734,   6565,   6586,   7263,   7909,
#               7931,   8716,
#             ...
#             248722, 249126, 249615, 250032, 250506, 250918, 251389, 251896,
#             252709, 253147],
#            dtype='int64', length=332)), (('LGA', 'TPA'), Int64Index([   141,    180,    286,    290,    330,    930,    955,   1005,
#               1012,   1076,
#             ...
#             251669, 251723, 251742, 251747, 252489, 252501, 252506, 252553,
#             252944, 252973],
#            dtype='int64', length=1852)), (('LGA', 'TVC'), Int64Index([133061, 133064, 133065, 138690, 139408, 139412, 139413, 144715,
#             145735, 145739, 145740, 151085, 151088, 151091, 157404, 157407,
#             162549, 163393, 163396, 168911, 169759, 169762, 175484, 176009,
#             176220, 181853, 182353, 182596, 188133, 188655, 188859, 194379,
#             195116, 195119, 200612, 201329],
#            dtype='int64')), (('LGA', 'TYS'), Int64Index([ 70475,  71371,  72241,  73158,  74718,  75593,  76535,  77372,
#              78158,  79185,
#             ...
#             244166, 245038, 245944, 246838, 248343, 249194, 250100, 250981,
#             251958, 252767],
#            dtype='int64', length=167)), (('LGA', 'XNA'), Int64Index([   532,   1237,   1239,   2918,   3513,   3515,   4208,   4990,
#               4992,   5899,
#             ...
#             248706, 249595, 249596, 250489, 250490, 251372, 251373, 252267,
#             252268, 253133],
#            dtype='int64', length=441))])

# %%
for g, vals in gdf.groups.items():
    print(g, len(vals))
# Out:
# ('EWR', 'ALB') 169
# ('EWR', 'ANC') 13
# ('EWR', 'ATL') 4182
# ('EWR', 'AUS') 568
# ('EWR', 'AVL') 145
# ('EWR', 'AVP') 1
# ('EWR', 'BDL') 210
# ('EWR', 'BNA') 1797
# ('EWR', 'BOS') 4268
# ('EWR', 'BQN') 251
# ('EWR', 'BTV') 300
# ('EWR', 'BUF') 334
# ('EWR', 'BWI') 185
# ('EWR', 'BZN') 51
# ('EWR', 'CAE') 21
# ('EWR', 'CHS') 986
# ('EWR', 'CLE') 1171
# ('EWR', 'CLT') 3921
# ('EWR', 'CMH') 763
# ('EWR', 'CVG') 1187
# ('EWR', 'DAY') 566
# ('EWR', 'DCA') 1309
# ('EWR', 'DEN') 2243
# ('EWR', 'DFW') 2224
# ('EWR', 'DSM') 179
# ('EWR', 'DTW') 2149
# ('EWR', 'EGE') 80
# ('EWR', 'FLL') 2909
# ('EWR', 'GRR') 490
# ('EWR', 'GSO') 644
# ('EWR', 'GSP') 518
# ('EWR', 'HDN') 13
# ('EWR', 'HNL') 301
# ('EWR', 'HOU') 784
# ('EWR', 'IAD') 629
# ('EWR', 'IAH') 3073
# ('EWR', 'IND') 1239
# ('EWR', 'JAC') 19
# ('EWR', 'JAX') 998
# ('EWR', 'LAS') 1555
# ('EWR', 'LAX') 4226
# ('EWR', 'MCI') 995
# ('EWR', 'MCO') 4164
# ('EWR', 'MDT') 5
# ('EWR', 'MDW') 1537
# ('EWR', 'MEM') 660
# ('EWR', 'MHT') 324
# ('EWR', 'MIA') 2094
# ('EWR', 'MKE') 676
# ('EWR', 'MSN') 280
# ('EWR', 'MSP') 1485
# ('EWR', 'MSY') 982
# ('EWR', 'MTJ') 12
# ('EWR', 'OKC') 223
# ('EWR', 'OMA') 544
# ('EWR', 'ORD') 3272
# ('EWR', 'ORF') 211
# ('EWR', 'PBI') 1874
# ('EWR', 'PDX') 418
# ('EWR', 'PHL') 7
# ('EWR', 'PHX') 2002
# ('EWR', 'PIT') 353
# ('EWR', 'PVD') 169
# ('EWR', 'PWM') 392
# ('EWR', 'RDU') 741
# ('EWR', 'RIC') 1183
# ('EWR', 'ROC') 504
# ('EWR', 'RSW') 1160
# ('EWR', 'SAN') 884
# ('EWR', 'SAT') 205
# ('EWR', 'SAV') 557
# ('EWR', 'SBN') 6
# ('EWR', 'SDF') 529
# ('EWR', 'SEA') 1364
# ('EWR', 'SFO') 4539
# ('EWR', 'SJU') 949
# ('EWR', 'SLC') 285
# ('EWR', 'SNA') 657
# ('EWR', 'STL') 1740
# ('EWR', 'STT') 174
# ('EWR', 'SYR') 86
# ('EWR', 'TPA') 1833
# ('EWR', 'TUL') 201
# ('EWR', 'TVC') 20
# ('EWR', 'TYS') 238
# ('EWR', 'XNA') 195
# ('JFK', 'ABQ') 278
# ('JFK', 'ACK') 277
# ('JFK', 'ATL') 1701
# ('JFK', 'AUS') 1370
# ('JFK', 'BNA') 284
# ('JFK', 'BOS') 4111
# ('JFK', 'BQN') 535
# ('JFK', 'BTV') 1004
# ('JFK', 'BUF') 2164
# ('JFK', 'BUR') 289
# ('JFK', 'BWI') 282
# ('JFK', 'CHS') 587
# ('JFK', 'CLE') 280
# ('JFK', 'CLT') 2272
# ('JFK', 'CMH') 576
# ('JFK', 'CVG') 282
# ('JFK', 'DCA') 1686
# ('JFK', 'DEN') 579
# ('JFK', 'DFW') 474
# ('JFK', 'DTW') 198
# ('JFK', 'EGE') 85
# ('JFK', 'FLL') 3258
# ('JFK', 'HNL') 260
# ('JFK', 'HOU') 570
# ('JFK', 'HYA') 75
# ('JFK', 'IAD') 1604
# ('JFK', 'IAH') 7
# ('JFK', 'IND') 278
# ('JFK', 'JAC') 1
# ('JFK', 'JAX') 843
# ('JFK', 'LAS') 3355
# ('JFK', 'LAX') 10208
# ('JFK', 'LGB') 526
# ('JFK', 'MCO') 4467
# ('JFK', 'MIA') 2750
# ('JFK', 'MSP') 458
# ('JFK', 'MSY') 908
# ('JFK', 'MVY') 159
# ('JFK', 'OAK') 247
# ('JFK', 'ORD') 1265
# ('JFK', 'ORF') 282
# ('JFK', 'PBI') 1362
# ('JFK', 'PDX') 725
# ('JFK', 'PHL') 1
# ('JFK', 'PHX') 1784
# ('JFK', 'PIT') 384
# ('JFK', 'PSE') 289
# ('JFK', 'PSP') 17
# ('JFK', 'PWM') 1076
# ('JFK', 'RDU') 1770
# ('JFK', 'ROC') 1036
# ('JFK', 'RSW') 856
# ('JFK', 'SAN') 1402
# ('JFK', 'SAT') 242
# ('JFK', 'SAV') 514
# ('JFK', 'SEA') 1815
# ('JFK', 'SFO') 7368
# ('JFK', 'SJC') 252
# ('JFK', 'SJU') 4027
# ('JFK', 'SLC') 1706
# ('JFK', 'SMF') 246
# ('JFK', 'SRQ') 370
# ('JFK', 'STT') 450
# ('JFK', 'SYR') 937
# ('JFK', 'TPA') 2019
# ('LGA', 'AGS') 3
# ('LGA', 'ATL') 6925
# ('LGA', 'AVL') 2
# ('LGA', 'BGR') 274
# ('LGA', 'BHM') 124
# ('LGA', 'BNA') 2600
# ('LGA', 'BOS') 3230
# ('LGA', 'BTV') 229
# ('LGA', 'BUF') 169
# ('LGA', 'BZN') 15
# ('LGA', 'CAE') 382
# ('LGA', 'CAK') 708
# ('LGA', 'CHO') 329
# ('LGA', 'CHS') 574
# ('LGA', 'CLE') 2111
# ('LGA', 'CLT') 3431
# ('LGA', 'CMH') 1816
# ('LGA', 'CVG') 78
# ('LGA', 'DAL') 15
# ('LGA', 'DAY') 490
# ('LGA', 'DCA') 3753
# ('LGA', 'DEN') 2939
# ('LGA', 'DFW') 3789
# ('LGA', 'DSM') 1
# ('LGA', 'DTW') 3663
# ('LGA', 'EYW') 32
# ('LGA', 'FLL') 3304
# ('LGA', 'GRR') 266
# ('LGA', 'GSO') 868
# ('LGA', 'GSP') 3
# ('LGA', 'HOU') 905
# ('LGA', 'IAD') 1091
# ('LGA', 'IAH') 2346
# ('LGA', 'ILM') 223
# ('LGA', 'IND') 49
# ('LGA', 'JAX') 67
# ('LGA', 'LIT') 204
# ('LGA', 'MCI') 406
# ('LGA', 'MCO') 3078
# ('LGA', 'MDW') 1937
# ('LGA', 'MEM') 3
# ('LGA', 'MHT') 146
# ('LGA', 'MIA') 5084
# ('LGA', 'MKE') 1176
# ('LGA', 'MSN') 188
# ('LGA', 'MSP') 2220
# ('LGA', 'MSY') 738
# ('LGA', 'MYR') 11
# ('LGA', 'OMA') 87
# ('LGA', 'ORD') 7052
# ('LGA', 'ORF') 1014
# ('LGA', 'PBI') 2307
# ('LGA', 'PHL') 702
# ('LGA', 'PIT') 262
# ('LGA', 'PWM') 131
# ('LGA', 'RDU') 2499
# ('LGA', 'RIC') 1135
# ('LGA', 'ROA') 125
# ('LGA', 'ROC') 254
# ('LGA', 'RSW') 569
# ('LGA', 'SAV') 368
# ('LGA', 'SBN') 2
# ('LGA', 'SDF') 542
# ('LGA', 'SRQ') 496
# ('LGA', 'STL') 2065
# ('LGA', 'SYR') 332
# ('LGA', 'TPA') 1852
# ('LGA', 'TVC') 36
# ('LGA', 'TYS') 167
# ('LGA', 'XNA') 441

# %%
gdf.agg({'count'})
# Out:
#              year month   day dep_delay arr_delay carrier air_time distance  \
#             count count count     count     count   count    count    count
# origin dest
# EWR    ALB    169   169   169       169       169     169      169      169
#        ANC     13    13    13        13        13      13       13       13
#        ATL   4182  4182  4182      4182      4182    4182     4182     4182
#        AUS    568   568   568       568       568     568      568      568
#        AVL    145   145   145       145       145     145      145      145
# ...           ...   ...   ...       ...       ...     ...      ...      ...
# LGA    SYR    332   332   332       332       332     332      332      332
#        TPA   1852  1852  1852      1852      1852    1852     1852     1852
#        TVC     36    36    36        36        36      36       36       36
#        TYS    167   167   167       167       167     167      167      167
#        XNA    441   441   441       441       441     441      441      441
#
#              hour
#             count
# origin dest
# EWR    ALB    169
#        ANC     13
#        ATL   4182
#        AUS    568
#        AVL    145
# ...           ...
# LGA    SYR    332
#        TPA   1852
#        TVC     36
#        TYS    167
#        XNA    441
#
# [221 rows x 9 columns]

# %%
gdf.agg({'year':'count'}).rename(columns={'year':'num'})
# Out:
#               num
# origin dest
# EWR    ALB    169
#        ANC     13
#        ATL   4182
#        AUS    568
#        AVL    145
# ...           ...
# LGA    SYR    332
#        TPA   1852
#        TVC     36
#        TYS    167
#        XNA    441
#
# [221 rows x 1 columns]

# %% [markdown]
# 2. Escribe un programa Pandas para calcula la media, desviación estándar, min y max del retraso total de cada orgige-destino.

# %%
df['total_delay'] = df['dep_delay']+df['arr_delay']
df
# Out:
#         year  month  day  dep_delay  arr_delay carrier origin dest  air_time  \
# 1       2014      1    1         14         13      AA    JFK  LAX       359
# 2       2014      1    1         -3         13      AA    JFK  LAX       363
# 3       2014      1    1          2          9      AA    JFK  LAX       351
# 4       2014      1    1         -8        -26      AA    LGA  PBI       157
# 5       2014      1    1          2          1      AA    JFK  LAX       350
# ...      ...    ...  ...        ...        ...     ...    ...  ...       ...
# 253312  2014     10   31          1        -30      UA    LGA  IAH       201
# 253313  2014     10   31         -5        -14      UA    EWR  IAH       189
# 253314  2014     10   31         -8         16      MQ    LGA  RDU        83
# 253315  2014     10   31         -4         15      MQ    LGA  DTW        75
# 253316  2014     10   31         -5          1      MQ    LGA  SDF       110
#
#         distance  hour  total_delay
# 1           2475     9           27
# 2           2475    11           10
# 3           2475    19           11
# 4           1035     7          -34
# 5           2475    13            3
# ...          ...   ...          ...
# 253312      1416    14          -29
# 253313      1400     8          -19
# 253314       431    11            8
# 253315       502    11           11
# 253316       659     8           -4
#
# [253316 rows x 12 columns]

# %%
gdf = df.groupby(['origin','dest'])
gdf.first()
# Out:
#              year  month  day  dep_delay  arr_delay carrier  air_time  \
# origin dest
# EWR    ALB   2014      1    2         -2        -25      EV        30
#        ANC   2014      6    7          1        -16      UA       415
#        ATL   2014      1    1         -7        -14      DL       118
#        AUS   2014      1    1         -4        -16      WN       247
#        AVL   2014      1    1        148        146      EV       101
# ...           ...    ...  ...        ...        ...     ...       ...
# LGA    SYR   2014      1    7          6        -10      EV        44
#        TPA   2014      1    1         -8          1      B6       165
#        TVC   2014      6   14         -7        -24      EV        94
#        TYS   2014      4    1         -8         -5      MQ        96
#        XNA   2014      1    1         -2          6      MQ       194
#
#              distance  hour  total_delay
# origin dest
# EWR    ALB        143     7          -27
#        ANC       3370    16          -15
#        ATL        746    14          -21
#        AUS       1504     9          -20
#        AVL        583    16          294
# ...               ...   ...          ...
# LGA    SYR        198    11           -4
#        TPA       1010    15           -7
#        TVC        655     7          -31
#        TYS        647    13          -13
#        XNA       1147     7            4
#
# [221 rows x 10 columns]

# %%
agdf = gdf.agg({'total_delay':['mean','std','min','max']})
print(agdf)
# Out:
#             total_delay
#                    mean         std min   max
# origin dest
# EWR    ALB    35.230769   92.478247 -36   618
#        ANC    15.307692   43.453777 -30   121
#        ATL    32.235533  114.946191 -47  2177
#        AUS     5.871479   63.006811 -62   539
#        AVL    24.903448   82.071727 -33   625
# ...                 ...         ...  ..   ...
# LGA    SYR    23.346386   88.091602 -54   844
#        TPA    15.267279   80.570698 -57   964
#        TVC    71.500000  183.741200 -41   765
#        TYS    17.305389   57.004937 -44   291
#        XNA     6.911565   53.977890 -64   320
#
# [221 rows x 4 columns]

# %% [markdown]
# 3. Escribe un programa Pandas para dividir un conjunto de datos y agruparlos por dos columnas, y luego ordenar los resultados agregados dentro de los grupos.
#
# En el siguiente conjunto de datos de vuelos, agrupar "date" (fecha completa) y "carrier". Luego ordenar la suma de 'total_delay' dentro de los grupos.

# %%
df['date'] = pd.to_datetime(df[['year', 'month', 'day']])
df
# Out:
#         year  month  day  dep_delay  arr_delay carrier origin dest  air_time  \
# 1       2014      1    1         14         13      AA    JFK  LAX       359
# 2       2014      1    1         -3         13      AA    JFK  LAX       363
# 3       2014      1    1          2          9      AA    JFK  LAX       351
# 4       2014      1    1         -8        -26      AA    LGA  PBI       157
# 5       2014      1    1          2          1      AA    JFK  LAX       350
# ...      ...    ...  ...        ...        ...     ...    ...  ...       ...
# 253312  2014     10   31          1        -30      UA    LGA  IAH       201
# 253313  2014     10   31         -5        -14      UA    EWR  IAH       189
# 253314  2014     10   31         -8         16      MQ    LGA  RDU        83
# 253315  2014     10   31         -4         15      MQ    LGA  DTW        75
# 253316  2014     10   31         -5          1      MQ    LGA  SDF       110
#
#         distance  hour  total_delay       date
# 1           2475     9           27 2014-01-01
# 2           2475    11           10 2014-01-01
# 3           2475    19           11 2014-01-01
# 4           1035     7          -34 2014-01-01
# 5           2475    13            3 2014-01-01
# ...          ...   ...          ...        ...
# 253312      1416    14          -29 2014-10-31
# 253313      1400     8          -19 2014-10-31
# 253314       431    11            8 2014-10-31
# 253315       502    11           11 2014-10-31
# 253316       659     8           -4 2014-10-31
#
# [253316 rows x 13 columns]

# %%
df.info()

gdf = df.groupby(['date', 'carrier']).agg({"total_delay": sum})
gdf
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 253316 entries, 1 to 253316
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   year         253316 non-null  int64
#  1   month        253316 non-null  int64
#  2   day          253316 non-null  int64
#  3   dep_delay    253316 non-null  int64
#  4   arr_delay    253316 non-null  int64
#  5   carrier      253316 non-null  object
#  6   origin       253316 non-null  object
#  7   dest         253316 non-null  object
#  8   air_time     253316 non-null  int64
#  9   distance     253316 non-null  int64
#  10  hour         253316 non-null  int64
#  11  total_delay  253316 non-null  int64
#  12  date         253316 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(9), object(3)
# memory usage: 27.1+ MB
#                     total_delay
# date       carrier
# 2014-01-01 AA              1017
#            AS                11
#            B6              9383
#            DL               545
#            EV              4675
# ...                         ...
# 2014-10-31 MQ               -24
#            UA              4862
#            US               -27
#            VX                14
#            WN              -909
#
# [3938 rows x 1 columns]

# %%
gdf["total_delay"].groupby(level=0, group_keys=False).nlargest()
# Out:
# date        carrier
# 2014-01-01  B6         9383
#             UA         5897
#             EV         4675
#             MQ         3122
#             WN         2744
#                        ...
# 2014-10-31  UA         4862
#             AA         3090
#             VX           14
#             HA           -4
#             F9          -20
# Name: total_delay, Length: 1520, dtype: int64

# %% [markdown]
# 4. Escribe un programa Pandas para contar el múmero de retrasos de salida por mes y origen.

# %% [markdown]
# 5. Escribe un programa Pandas para cargar los datos de productos y ventas del archivo FoodMarket.xlsx y mézclalos en un solo dataframe.

# %%
# Productos

df_prods = pd.read_excel('./data/Foodmarket.xlsx', sheet_name='Products')
df_prods.info()
df_prods.sort_values(['Product'], ascending=True,inplace=True)
print(df_prods.head())
print(df_prods.tail())
df_prods.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   70 non-null     int64
#  1   Name.x    70 non-null     object
#  2   provider  70 non-null     int64
#  3   Price     70 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.3+ KB
#     Product                                   Name.x  provider      Price
# 10        1                         American cheeses         1   8.913593
# 12        2  Appellation d'Origine Contrôlée cheeses         1  10.705655
# 55        3                          Apple cultivars         1  11.280984
# 58        4                             Bacon dishes         1  10.144121
# 54        5                        Bacon substitutes         1  11.089174
#     Product             Name.x  provider      Price
# 61       66     Turkish dishes         4  41.352309
# 20       67  Twice-baked foods         4  41.740085
# 6        68     Vegetable oils         4  35.583480
# 64       69         Vegetables         4  37.070492
# 60       70             Vodkas         4  40.404487
#          Product   provider      Price
# count  70.000000  70.000000  70.000000
# mean   35.500000   1.828571  18.309713
# std    20.351085   1.049105  10.454415
# min     1.000000   1.000000   8.236004
# 25%    18.250000   1.000000   9.990970
# 50%    35.500000   1.000000  11.158073
# 75%    52.750000   3.000000  29.619032
# max    70.000000   4.000000  41.740085

# %%
# Ventas

df_purch = pd.read_excel('./data/Foodmarket.xlsx', sheet_name='Purchases')
df_purch.info()

print(df_purch.head())
print(df_purch.tail())
df_purch.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501 entries, 0 to 1500
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Code      1501 non-null   int64
#  1   Product   1501 non-null   int64
#  2   Seller    1501 non-null   int64
#  3   Buyer     1501 non-null   int64
#  4   Fecha     1501 non-null   datetime64[ns]
#  5   Quantity  1501 non-null   int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 70.5 KB
#    Code  Product  Seller  Buyer      Fecha  Quantity
# 0     1       15      37     90 2020-11-10        25
# 1     2       46      32     51 2020-09-19        16
# 2     3       44      27    166 2019-02-19        25
# 3     4       52      21     68 2020-06-08        40
# 4     5       20      21    185 2019-01-18        36
#       Code  Product  Seller  Buyer      Fecha  Quantity
# 1496  1497       10      18    199 2020-11-23        34
# 1497  1498       63      58     38 2020-03-13        35
# 1498  1499       28       5     81 2020-03-02        31
# 1499  1500       21       2    194 2021-02-18        35
# 1500  1501       33       8    120 2020-03-13        12
#               Code      Product       Seller        Buyer     Quantity
# count  1501.000000  1501.000000  1501.000000  1501.000000  1501.000000
# mean    751.000000    34.712192    28.788141   104.956696    31.341106
# std     433.445691    19.974111    16.557750    59.825625     7.333365
# min       1.000000     1.000000     1.000000     1.000000    12.000000
# 25%     376.000000    17.000000    14.000000    51.000000    26.000000
# 50%     751.000000    34.000000    28.000000   106.000000    31.000000
# 75%    1126.000000    52.000000    43.000000   158.000000    37.000000
# max    1501.000000    70.000000    58.000000   207.000000    50.000000

# %%
# !pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (0.9.0)

# %%
from tabulate import tabulate

# %%
# combinado
df = pd.merge(df_purch,df_prods,on='Product')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1501 entries, 0 to 1500
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Code      1501 non-null   int64
#  1   Product   1501 non-null   int64
#  2   Seller    1501 non-null   int64
#  3   Buyer     1501 non-null   int64
#  4   Fecha     1501 non-null   datetime64[ns]
#  5   Quantity  1501 non-null   int64
#  6   Name.x    1501 non-null   object
#  7   provider  1501 non-null   int64
#  8   Price     1501 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(1)
# memory usage: 117.3+ KB

# %%
df.rename(columns={'Name.x': 'Product_Name'}, inplace = True)
df.info()
df.describe()
print(tabulate (df.head(),headers='keys'))
print('/n')
print(tabulate(df.tail(),headers='keys'))
print('/n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1501 entries, 0 to 1500
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Code          1501 non-null   int64
#  1   Product       1501 non-null   int64
#  2   Seller        1501 non-null   int64
#  3   Buyer         1501 non-null   int64
#  4   Fecha         1501 non-null   datetime64[ns]
#  5   Quantity      1501 non-null   int64
#  6   Product_Name  1501 non-null   object
#  7   provider      1501 non-null   int64
#  8   Price         1501 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(1)
# memory usage: 117.3+ KB
#       Code    Product    Seller    Buyer  Fecha                  Quantity  Product_Name      provider    Price
# --  ------  ---------  --------  -------  -------------------  ----------  --------------  ----------  -------
#  0       1         15        37       90  2020-11-10 00:00:00          25  Cheese soups             1  10.1163
#  1      79         15        42      205  2020-07-28 00:00:00          26  Cheese soups             1  10.1163
#  2     164         15        55      101  2020-11-11 00:00:00          46  Cheese soups             1  10.1163
#  3     196         15        15      121  2021-03-15 00:00:00          40  Cheese soups             1  10.1163
#  4     291         15        15      174  2019-12-13 00:00:00          45  Cheese soups             1  10.1163
# /n
#         Code    Product    Seller    Buyer  Fecha                  Quantity  Product_Name          provider    Price
# ----  ------  ---------  --------  -------  -------------------  ----------  ------------------  ----------  -------
# 1496    1176         21        36       79  2019-11-26 00:00:00          28  Doughnut varieties           1    8.236
# 1497    1326         21        21      114  2020-09-27 00:00:00          39  Doughnut varieties           1    8.236
# 1498    1414         21        19       76  2019-03-25 00:00:00          31  Doughnut varieties           1    8.236
# 1499    1442         21        49       23  2020-04-20 00:00:00          27  Doughnut varieties           1    8.236
# 1500    1500         21         2      194  2021-02-18 00:00:00          35  Doughnut varieties           1    8.236
# /n

# %% [markdown]
# 6. Escribe un programa Pandas para extraer información sobre el número de compras totales y el monto total por nombre de producto y año.

# %%
gdf = df.groupby(['Product_Name','Fecha'])
gdf.groups
# Out:
# {('American cheeses', 2019-05-26 00:00:00): [1230], ('American cheeses', 2019-06-28 00:00:00): [1234], ('American cheeses', 2019-07-26 00:00:00): [1246], ('American cheeses', 2019-08-01 00:00:00): [1237], ('American cheeses', 2019-09-10 00:00:00): [1233], ('American cheeses', 2019-11-08 00:00:00): [1235], ('American cheeses', 2020-01-16 00:00:00): [1232], ('American cheeses', 2020-02-16 00:00:00): [1250], ('American cheeses', 2020-03-03 00:00:00): [1238], ('American cheeses', 2020-05-05 00:00:00): [1231], ('American cheeses', 2020-06-03 00:00:00): [1240, 1243], ('American cheeses', 2020-06-06 00:00:00): [1249], ('American cheeses', 2020-06-18 00:00:00): [1239], ('American cheeses', 2020-07-13 00:00:00): [1244], ('American cheeses', 2020-08-23 00:00:00): [1241], ('American cheeses', 2020-09-17 00:00:00): [1248], ('American cheeses', 2020-11-12 00:00:00): [1247], ('American cheeses', 2020-12-05 00:00:00): [1242], ('American cheeses', 2021-04-04 00:00:00): [1251], ('American cheeses', 2021-04-21 00:00:00): [1245], ('American cheeses', 2021-05-01 00:00:00): [1236], ('Appellation d'Origine Contrôlée cheeses', 2019-01-05 00:00:00): [1333], ('Appellation d'Origine Contrôlée cheeses', 2019-02-19 00:00:00): [1334], ('Appellation d'Origine Contrôlée cheeses', 2019-03-15 00:00:00): [1330], ('Appellation d'Origine Contrôlée cheeses', 2019-03-18 00:00:00): [1328], ('Appellation d'Origine Contrôlée cheeses', 2019-06-07 00:00:00): [1332], ('Appellation d'Origine Contrôlée cheeses', 2019-08-07 00:00:00): [1336], ('Appellation d'Origine Contrôlée cheeses', 2019-09-12 00:00:00): [1331], ('Appellation d'Origine Contrôlée cheeses', 2019-11-28 00:00:00): [1326], ('Appellation d'Origine Contrôlée cheeses', 2020-02-24 00:00:00): [1325], ('Appellation d'Origine Contrôlée cheeses', 2020-02-28 00:00:00): [1337], ('Appellation d'Origine Contrôlée cheeses', 2020-04-13 00:00:00): [1327], ('Appellation d'Origine Contrôlée cheeses', 2020-08-03 00:00:00): [1329], ('Appellation d'Origine Contrôlée cheeses', 2020-10-17 00:00:00): [1335], ('Apple cultivars', 2019-01-30 00:00:00): [419], ('Apple cultivars', 2019-02-03 00:00:00): [433], ('Apple cultivars', 2019-03-03 00:00:00): [437], ('Apple cultivars', 2019-03-24 00:00:00): [439], ('Apple cultivars', 2019-04-03 00:00:00): [432], ('Apple cultivars', 2019-05-11 00:00:00): [425], ('Apple cultivars', 2019-06-14 00:00:00): [418], ('Apple cultivars', 2019-07-01 00:00:00): [416], ('Apple cultivars', 2019-07-15 00:00:00): [431], ('Apple cultivars', 2019-08-12 00:00:00): [417], ('Apple cultivars', 2019-09-08 00:00:00): [420], ('Apple cultivars', 2019-10-21 00:00:00): [441], ('Apple cultivars', 2019-12-13 00:00:00): [429], ('Apple cultivars', 2020-01-01 00:00:00): [423], ('Apple cultivars', 2020-05-21 00:00:00): [438], ('Apple cultivars', 2020-06-16 00:00:00): [426], ('Apple cultivars', 2020-07-01 00:00:00): [415], ('Apple cultivars', 2020-07-03 00:00:00): [435], ('Apple cultivars', 2020-08-03 00:00:00): [424], ('Apple cultivars', 2020-08-21 00:00:00): [421], ('Apple cultivars', 2020-09-05 00:00:00): [434], ('Apple cultivars', 2020-09-10 00:00:00): [428], ('Apple cultivars', 2020-10-29 00:00:00): [430], ('Apple cultivars', 2021-01-21 00:00:00): [440], ('Apple cultivars', 2021-02-05 00:00:00): [436], ('Apple cultivars', 2021-03-30 00:00:00): [422], ('Apple cultivars', 2021-04-11 00:00:00): [427], ('Bacon dishes', 2019-02-03 00:00:00): [1203], ('Bacon dishes', 2019-02-24 00:00:00): [1202], ('Bacon dishes', 2019-04-27 00:00:00): [1198], ('Bacon dishes', 2019-05-06 00:00:00): [1197], ('Bacon dishes', 2019-06-15 00:00:00): [1204], ('Bacon dishes', 2019-07-06 00:00:00): [1205], ('Bacon dishes', 2019-07-18 00:00:00): [1200], ('Bacon dishes', 2019-09-02 00:00:00): [1186], ('Bacon dishes', 2019-10-05 00:00:00): [1207], ('Bacon dishes', 2020-06-20 00:00:00): [1206], ('Bacon dishes', 2020-07-31 00:00:00): [1199], ('Bacon dishes', 2020-08-12 00:00:00): [1209], ('Bacon dishes', 2020-08-29 00:00:00): [1188], ('Bacon dishes', 2020-10-2 ...

# %%
gdf = df.groupby(['Product_Name',df['Fecha'].dt.year])
gdf.groups
# Out:
# {('American cheeses', 2019): [1230, 1233, 1234, 1235, 1237, 1246], ('American cheeses', 2020): [1231, 1232, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1247, 1248, 1249, 1250], ('American cheeses', 2021): [1236, 1245, 1251], ('Appellation d'Origine Contrôlée cheeses', 2019): [1326, 1328, 1330, 1331, 1332, 1333, 1334, 1336], ('Appellation d'Origine Contrôlée cheeses', 2020): [1325, 1327, 1329, 1335, 1337], ('Apple cultivars', 2019): [416, 417, 418, 419, 420, 425, 429, 431, 432, 433, 437, 439, 441], ('Apple cultivars', 2020): [415, 421, 423, 424, 426, 428, 430, 434, 435, 438], ('Apple cultivars', 2021): [422, 427, 436, 440], ('Bacon dishes', 2019): [1186, 1197, 1198, 1200, 1202, 1203, 1204, 1205, 1207], ('Bacon dishes', 2020): [1188, 1192, 1193, 1195, 1196, 1199, 1206, 1209], ('Bacon dishes', 2021): [1187, 1189, 1190, 1191, 1194, 1201, 1208], ('Bacon substitutes', 2019): [269, 272, 273, 274, 275, 276, 277, 278, 279, 281, 283, 286, 288, 290, 291, 292, 293, 295, 297, 298], ('Bacon substitutes', 2020): [267, 268, 270, 271, 280, 282, 285, 287, 289, 294, 296, 299], ('Bacon substitutes', 2021): [284], ('Basil cultivars', 2019): [1392, 1394, 1395, 1398, 1402, 1403, 1404, 1406], ('Basil cultivars', 2020): [1391, 1393, 1399, 1400, 1405, 1407], ('Basil cultivars', 2021): [1396, 1397, 1401], ('Breads', 2019): [1087, 1090, 1091, 1093, 1098, 1099, 1100, 1102, 1104, 1106, 1108, 1109, 1111], ('Breads', 2020): [1084, 1086, 1089, 1092, 1094, 1095, 1096, 1101, 1105, 1107, 1110], ('Breads', 2021): [1085, 1088, 1097, 1103], ('Breakfast beverages', 2019): [464, 466, 467, 470, 472, 473, 474, 476, 478, 479, 480, 481], ('Breakfast beverages', 2020): [462, 463, 465, 468, 471, 475, 477, 482], ('Breakfast beverages', 2021): [469], ('Breakfast cereals', 2019): [553, 554, 560, 561, 563, 565, 566, 567, 569], ('Breakfast cereals', 2020): [549, 550, 551, 557, 558, 559, 562, 570, 571], ('Breakfast cereals', 2021): [552, 555, 556, 564, 568], ('Breakfast foods', 2019): [1066, 1067, 1069, 1073, 1074, 1075, 1077, 1078, 1079, 1080], ('Breakfast foods', 2020): [1064, 1065, 1068, 1070, 1071, 1072, 1076, 1082, 1083], ('Breakfast foods', 2021): [1081], ('British cheeses', 2019): [1379, 1385, 1386, 1389], ('British cheeses', 2020): [1380, 1381, 1383, 1384, 1387, 1388, 1390], ('British cheeses', 2021): [1382], ('Cakes', 2019): [848, 849, 852, 857, 861, 862, 863, 864, 867, 869, 870], ('Cakes', 2020): [850, 851, 853, 854, 855, 856, 858, 859, 865, 866, 868, 871, 872, 873, 874, 876], ('Cakes', 2021): [860, 875], ('Candies', 2019): [398, 401, 406, 407, 408, 411, 412, 414], ('Candies', 2020): [394, 395, 397, 399, 402, 405, 409, 413], ('Candies', 2021): [396, 400, 403, 404, 410], ('Cheese soups', 2019): [4, 5, 9, 10, 11, 13, 14, 25, 27, 28], ('Cheese soups', 2020): [0, 1, 2, 6, 12, 15, 19, 20, 21, 22, 23, 26, 29], ('Cheese soups', 2021): [3, 7, 8, 16, 17, 18, 24], ('Cheeses', 2019): [707, 709, 710, 713, 715, 716, 718], ('Cheeses', 2020): [706, 708, 712, 714, 719, 720, 721, 722, 723, 724], ('Cheeses', 2021): [711, 717], ('Christmas dishes (list)', 2019): [1274, 1276, 1278, 1279, 1284, 1285, 1287, 1288, 1291, 1294, 1296, 1297], ('Christmas dishes (list)', 2020): [1275, 1277, 1280, 1281, 1282, 1283, 1286, 1289, 1290, 1292, 1295, 1298], ('Christmas dishes (list)', 2021): [1293], ('Cocktails', 2019): [745, 747, 748, 750, 751, 753, 754, 757, 758, 760, 762, 764, 765, 766, 767], ('Cocktails', 2020): [749, 755, 756, 759, 768], ('Cocktails', 2021): [746, 752, 761, 763], ('Cookies', 2019): [1217, 1218, 1220, 1223, 1224, 1226, 1227, 1229], ('Cookies', 2020): [1210, 1211, 1212, 1213, 1219, 1222, 1225], ('Cookies', 2021): [1214, 1215, 1216, 1221, 1228], ('Diets', 2019): [109, 110, 112, 113, 115, 116, 117, 118], ('Diets', 2020): [114, 119, 121, 122, 124], ('Diets', 2021): [111, 120, 123], ('Dishes using coconut milk', 2019): [1252, 1255, 1256, 1259, 1261, 1263, 1265, 1272], ('Dishes using coconut milk', 2020): [1257, 1258, 1262, 1264, 1266, 1267, 1269, 1270, 1273], ('Dishes using coconut milk',  ...

# %%
gdf = df.groupby(['Product_Name',df['Fecha'].dt.year]).agg({'Quantity':sum})
gdf
# Out:
#                                                Quantity
# Product_Name                            Fecha
# American cheeses                        2019        183
#                                         2020        384
#                                         2021         97
# Appellation d'Origine Contrôlée cheeses 2019        241
#                                         2020        184
# ...                                                 ...
# Vegetables                              2019        249
#                                         2020        108
# Vodkas                                  2019        348
#                                         2020        187
#                                         2021         66
#
# [205 rows x 1 columns]
